# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from collections import Counter
from num2words import num2words

import nltk 
import os 
import string
import numpy as np
import copy
import pandas as pd
import pickle
import re
import math

# %%
pip install num2words
# Out:
# Requirement already satisfied: num2words in c:\programdata\anaconda3\lib\site-packages (0.5.10)
# Requirement already satisfied: docopt>=0.6.2 in c:\programdata\anaconda3\lib\site-packages (from num2words) (0.6.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
title = "used"

os.chdir("C:/mini_newsgroups/comp.graphics")

paths = []
for (dirpath, dirnames, filenames) in os.walk(str(os.getcwd())+"/"+title+"/"):
    for i in filenames:
        paths.append(str(dirpath)+str("/")+i)

# %%
for i in range(len(filenames)):
    print(dirpath+'/'+filenames[i])
# Out:
# C:\mini_newsgroups\comp.graphics/used//37916
# C:\mini_newsgroups\comp.graphics/used//37921
# C:\mini_newsgroups\comp.graphics/used//37930
# C:\mini_newsgroups\comp.graphics/used//37936
# C:\mini_newsgroups\comp.graphics/used//37942
# C:\mini_newsgroups\comp.graphics/used//37944
# C:\mini_newsgroups\comp.graphics/used//37947
# C:\mini_newsgroups\comp.graphics/used//38220
# C:\mini_newsgroups\comp.graphics/used//38224
# C:\mini_newsgroups\comp.graphics/used//38244
# C:\mini_newsgroups\comp.graphics/used//38251
# C:\mini_newsgroups\comp.graphics/used//38264
# C:\mini_newsgroups\comp.graphics/used//38266
# C:\mini_newsgroups\comp.graphics/used//38271
# C:\mini_newsgroups\comp.graphics/used//38355
# C:\mini_newsgroups\comp.graphics/used//38369
# C:\mini_newsgroups\comp.graphics/used//38370
# C:\mini_newsgroups\comp.graphics/used//38375
# C:\mini_newsgroups\comp.graphics/used//38379
# C:\mini_newsgroups\comp.graphics/used//38380
# C:\mini_newsgroups\comp.graphics/used//38386
# C:\mini_newsgroups\comp.graphics/used//38402
# C:\mini_newsgroups\comp.graphics/used//38409
# C:\mini_newsgroups\comp.graphics/used//38421
# C:\mini_newsgroups\comp.graphics/used//38439
# C:\mini_newsgroups\comp.graphics/used//38454
# C:\mini_newsgroups\comp.graphics/used//38459
# C:\mini_newsgroups\comp.graphics/used//38464
# C:\mini_newsgroups\comp.graphics/used//38466
# C:\mini_newsgroups\comp.graphics/used//38470
# C:\mini_newsgroups\comp.graphics/used//38473
# C:\mini_newsgroups\comp.graphics/used//38489
# C:\mini_newsgroups\comp.graphics/used//38491
# C:\mini_newsgroups\comp.graphics/used//38518
# C:\mini_newsgroups\comp.graphics/used//38562
# C:\mini_newsgroups\comp.graphics/used//38571
# C:\mini_newsgroups\comp.graphics/used//38573
# C:\mini_newsgroups\comp.graphics/used//38577
# C:\mini_newsgroups\comp.graphics/used//38603
# C:\mini_newsgroups\comp.graphics/used//38606
# C:\mini_newsgroups\comp.graphics/used//38613
# C:\mini_newsgroups\comp.graphics/used//38622
# C:\mini_newsgroups\comp.graphics/used//38625
# C:\mini_newsgroups\comp.graphics/used//38628
# C:\mini_newsgroups\comp.graphics/used//38636
# C:\mini_newsgroups\comp.graphics/used//38670
# C:\mini_newsgroups\comp.graphics/used//38674
# C:\mini_newsgroups\comp.graphics/used//38683
# C:\mini_newsgroups\comp.graphics/used//38693
# C:\mini_newsgroups\comp.graphics/used//38699
# C:\mini_newsgroups\comp.graphics/used//38700
# C:\mini_newsgroups\comp.graphics/used//38704
# C:\mini_newsgroups\comp.graphics/used//38709
# C:\mini_newsgroups\comp.graphics/used//38750
# C:\mini_newsgroups\comp.graphics/used//38753
# C:\mini_newsgroups\comp.graphics/used//38755
# C:\mini_newsgroups\comp.graphics/used//38758
# C:\mini_newsgroups\comp.graphics/used//38761
# C:\mini_newsgroups\comp.graphics/used//38788
# C:\mini_newsgroups\comp.graphics/used//38835
# C:\mini_newsgroups\comp.graphics/used//38839
# C:\mini_newsgroups\comp.graphics/used//38843
# C:\mini_newsgroups\comp.graphics/used//38845
# C:\mini_newsgroups\comp.graphics/used//38846
# C:\mini_newsgroups\comp.graphics/used//38853
# C:\mini_newsgroups\comp.graphics/used//38856
# C:\mini_newsgroups\comp.graphics/used//38867
# C:\mini_newsgroups\comp.graphics/used//38880
# C:\mini_newsgroups\comp.graphics/used//38884
# C:\mini_newsgroups\comp.graphics/used//38893
# C:\mini_newsgroups\comp.graphics/used//38904
# C:\mini_newsgroups\comp.graphics/used//38907
# C:\mini_newsgroups\comp.graphics/used//38921
# C:\mini_newsgroups\comp.graphics/used//38925
# C:\mini_newsgroups\comp.graphics/used//38929
# C:\mini_newsgroups\comp.graphics/used//38936
# C:\mini_newsgroups\comp.graphics/used//38942
# C:\mini_newsgroups\comp.graphics/used//38965
# C:\mini_newsgroups\comp.graphics/used//38968
# C:\mini_newsgroups\comp.graphics/used//38980
# C:\mini_newsgroups\comp.graphics/used//38983
# C:\mini_newsgroups\comp.graphics/used//38998
# C:\mini_newsgroups\comp.graphics/used//39000
# C:\mini_newsgroups\comp.graphics/used//39008
# C:\mini_newsgroups\comp.graphics/used//39013
# C:\mini_newsgroups\comp.graphics/used//39017
# C:\mini_newsgroups\comp.graphics/used//39022
# C:\mini_newsgroups\comp.graphics/used//39027
# C:\mini_newsgroups\comp.graphics/used//39048
# C:\mini_newsgroups\comp.graphics/used//39049
# C:\mini_newsgroups\comp.graphics/used//39072
# C:\mini_newsgroups\comp.graphics/used//39078
# C:\mini_newsgroups\comp.graphics/used//39615
# C:\mini_newsgroups\comp.graphics/used//39620
# C:\mini_newsgroups\comp.graphics/used//39621
# C:\mini_newsgroups\comp.graphics/used//39659
# C:\mini_newsgroups\comp.graphics/used//39663
# C:\mini_newsgroups\comp.graphics/used//39664
# C:\mini_newsgroups\comp.graphics/used//39668
# C:\mini_newsgroups\comp.graphics/used//39675

# %%
def print_doc(id):
    file = open(dirpath+'/'+filenames[id],'r',encoding='cp1250')
    text = file.read().strip()
    file.close()
    print(text)
    
print_doc(0)
# Out:
# Path: cantaloupe.srv.cs.cmu.edu!crabapple.srv.cs.cmu.edu!fs7.ece.cmu.edu!europa.eng.gtefsd.com!gatech!asuvax!cs.utexas.edu!zaphod.mps.ohio-state.edu!saimiri.primate.wisc.edu!usenet.coe.montana.edu!news.u.washington.edu!uw-beaver!cs.ubc.ca!unixg.ubc.ca!kakwa.ucs.ualberta.ca!ersys!joth
# From: joth@ersys.edmonton.ab.ca (Joe Tham)
# Newsgroups: comp.graphics
# Subject: Where can I find SIPP?
# Message-ID: <yFXJ2B2w165w@ersys.edmonton.ab.ca>
# Date: Mon, 05 Apr 93 14:58:21 MDT
# Organization: Edmonton Remote Systems #2, Edmonton, AB, Canada
# Lines: 11
#
#         I recently got a file describing a library of rendering routines
# called SIPP (SImple Polygon Processor).  Could anyone tell me where I can
# FTP the source code and which is the newest version around?
#         Also, I've never used Renderman so I was wondering if Renderman
# is like SIPP?  ie. a library of rendering routines which one uses to make
# a program that creates the image...
#
#                                         Thanks,  Joe Tham
#
# --
# Joe Tham              joth@ersys.edmonton.ab.ca

# %%
def remove_stop_words(data):
    stop_words = stopwords.words('english')
    words = word_tokenize(str(data))
    new_text = ""
    for w in words:
        if w not in stop_words:
            new_text = new_text + " " + w
    return np.char.strip(new_text)


def remove_punctuation(data):
    symbols = "!\"#$%&()*+-./:;<=>?@[\]^_`{|}~\n"
    for i in range(len(symbols)):
        data = np.char.replace(data, symbols[i], '')
        data = np.char.replace(data, " ", " ")
    data = np.char.replace(data, ',', '')
    return data

def convert_lower_case(data):
    return np.char.lower(data)

def stemming(data):
    stemmer= PorterStemmer()
    tokens = word_tokenize(str(data))
    new_text = ""
    for w in tokens:
        new_text = new_text + " " + stemmer.stem(w)
    return np.char.strip(new_text)


def convert_numbers(data):
    data = np.char.replace(data, "0", " zero ")
    data = np.char.replace(data, "1", " one ")
    data = np.char.replace(data, "2", " two ")
    data = np.char.replace(data, "3", " three ")
    data = np.char.replace(data, "4", " four ")
    data = np.char.replace(data, "5", " five ")
    data = np.char.replace(data, "6", " six ")
    data = np.char.replace(data, "7", " seven ")
    data = np.char.replace(data, "8", " eight ")
    data = np.char.replace(data, "9", " nine ")
    return data


def remove_header(data):
    try:
        ind = data.index('\n\n')
        data = data[ind:]
    except:
        print("No Header")
    return data

def remove_apostrophe(data):
    return np.char.replace(data, "'", "")


def remove_single_characters(data):
    words = word_tokenize(str(data))
    new_text = ""
    for w in words:
        if len(w) > 1:
            new_text = new_text + " " + w
    return np.char.strip(new_text)

def preprocess(data):
   
        data = remove_header(data) 
        data = convert_lower_case(data)
        data = convert_numbers(data)
        data = remove_punctuation(data)
        data = remove_stop_words(data)
        data = remove_apostrophe(data)
        data = remove_single_characters(data)
        data = stemming(data) 
        return data

# %%
processed_text = []
for i in range(len(filenames)):
    file = open(dirpath+'/'+ filenames[i], 'r',encoding='cp1250',errors='ignore')
    text = file.read().strip()
    file.close()
    processed_text.append(word_tokenize(str(preprocess(text))))
    print(processed_text)
# Out:
# [['recent', 'got', 'file', 'describ', 'librari', 'render', 'routin', 'call', 'sipp', 'simpl', 'polygon', 'processor', 'could', 'anyon', 'tell', 'ftp', 'sourc', 'code', 'newest', 'version', 'around', 'also', 've', 'never', 'use', 'renderman', 'wonder', 'renderman', 'like', 'sipp', 'ie', 'librari', 'render', 'routin', 'one', 'use', 'make', 'program', 'creat', 'imag', 'thank', 'joe', 'thamjo', 'tham', 'jothersysedmontonabca']]
# [['recent', 'got', 'file', 'describ', 'librari', 'render', 'routin', 'call', 'sipp', 'simpl', 'polygon', 'processor', 'could', 'anyon', 'tell', 'ftp', 'sourc', 'code', 'newest', 'version', 'around', 'also', 've', 'never', 'use', 'renderman', 'wonder', 'renderman', 'like', 'sipp', 'ie', 'librari', 'render', 'routin', 'one', 'use', 'make', 'program', 'creat', 'imag', 'thank', 'joe', 'thamjo', 'tham', 'jothersysedmontonabca'], ['hello', 'everybodi', 'use', 'pixar', 'renderman', 'three', 'scene', 'descript', 'languag', 'creat', 'three', 'world', 'pleas', 'help', 'use', 'renderman', 'librari', 'next', 'document', 'nextstep', 'version', 'renderman', 'avail', 'creat', 'complic', 'scene', 'render', 'use', 'surfac', 'shader', 'bring', 'life', 'appli', 'shadow', 'reflectionsa', 'far', 'understand', 'defin', 'environment', 'shadow', 'map', 'produc', 'reflect', 'shadow', 'know', 'use', 'themani', 'advis', 'simpl', 'rib', 'exampl', 'appreciatedthank', 'advancealex', 'kolesov', 'moscow', 'russiatalu', 'imag', 'commun', 'corporationemail', 'alextalusmsksu', 'next', 'mail', 'accept']]
# [['recent', 'got', 'file', 'describ', 'librari', 'render', 'routin', 'call', 'sipp', 'simpl', 'polygon', 'processor', 'could', 'anyon', 'tell', 'ftp', 'sourc', 'code', 'newest', 'version', 'around', 'also', 've', 'never', 'use', 'renderman', 'wonder', 'renderman', 'like', 'sipp', 'ie', 'librari', 'render', 'routin', 'one', 'use', 'make', 'program', 'creat', 'imag', 'thank', 'joe', 'thamjo', 'tham', 'jothersysedmontonabca'], ['hello', 'everybodi', 'use', 'pixar', 'renderman', 'three', 'scene', 'descript', 'languag', 'creat', 'three', 'world', 'pleas', 'help', 'use', 'renderman', 'librari', 'next', 'document', 'nextstep', 'version', 'renderman', 'avail', 'creat', 'complic', 'scene', 'render', 'use', 'surfac', 'shader', 'bring', 'life', 'appli', 'shadow', 'reflectionsa', 'far', 'understand', 'defin', 'environment', 'shadow', 'map', 'produc', 'reflect', 'shadow', 'know', 'use', 'themani', 'advis', 'simpl', 'rib', 'exampl', 'appreciatedthank', 'advancealex', 'kolesov', 'moscow', 'russiatalu', 'imag', 'commun', 'corporationemail', 'alextalusmsksu', 'next', 'mail', 'accept'], ['anybodi', 'know', 'good', 'two', 'dgraphic', 'packag', 'avail', 'ibm', 'rs', 'six', 'zero', 'zero', 'zero', 'aix', 'look', 'someth', 'like', 'dec', 'gk', 'hewlettpackard', 'starbas', 'reason', 'good', 'support', 'differ', 'output', 'devic', 'like', 'plotter', 'termin', 'etc', 'tri', 'also', 'xgk', 'one', 'one', 'distribut', 'ibm', 'implement', 'phig', 'work', 'requir', 'output', 'devic', 'xwindow', 'salesman', 'ibm', 'familiar', 'graphic', 'expect', 'good', 'solut', 'ari', 'ari', 'suutari', 'aricarelfi', 'carelcomp', 'oy', 'lappeenranta', 'finland']]
# [['recent', 'got', 'file', 'describ', 'librari', 'render', 'routin', 'call', 'sipp', 'simpl', 'polygon', 'processor', 'could', 'anyon', 'tell', 'ftp', 'sourc', 'code', 'newest', 'version', 'around', 'also', 've', 'never', 'use', 'renderman', 'wonder', 'renderman', 'like', 'sipp', 'ie', 'librari', 'render', 'routin', 'one', 'use', 'make', 'program', 'creat', 'imag', 'thank', 'joe', 'thamjo', 'tham', 'jothersysedmontonabca'], ['hello', 'everybodi', 'use', 'pixar', 'renderman', 'three', 'scene', 'descript', 'languag', 'creat', 'three', 'world', 'pleas', 'help', 'use', 'renderman', 'librari', 'next', 'document', 'nextstep', 'version', 'renderman', 'avail', 'creat', 'complic', 'scene', 'render', 'use', 'surfac', 'shader', 'bring', 'life', 'appli', 'shadow', 'reflectionsa', 'far', 'understand', 'defin', 'environment', 'shadow', 'map', 'produc', 'reflect', 'shadow', 'know', 'use', 'themani', 'advis', 'simpl', 'rib', 'exampl', 'appreciatedthank', 'advancealex', 'kolesov', 'moscow', 'russiatalu', 'imag', 'commun', 'corporationemail', 'alextalusmsksu', 'next', 'mail', 'accept'], ['anybodi', 'know', 'good', 'two', 'dgraphic', 'packag', 'avail', 'ibm', 'rs', 'six', 'zero', 'zero', 'zero', 'aix', 'look', 'someth', 'like', 'dec', 'gk', 'hewlettpackard', 'starbas', 'reason', 'good', 'support', 'differ', 'output', 'devic', 'like', 'plotter', 'termin', 'etc', 'tri', 'also', 'xgk', 'one', 'one', 'distribut', 'ibm', 'implement', 'phig', 'work', 'requir', 'output', 'devic', 'xwindow', 'salesman', 'ibm', 'familiar', 'graphic', 'expect', 'good', 'solut', 'ari', 'ari', 'suutari', 'aricarelfi', 'carelcomp', 'oy', 'lappeenranta', 'finland'], ['requir', 'bgi', 'driver', 'super', 'vga', 'display', 'super', 'xvga', 'display', 'anyon', 'know', 'could', 'obtain', 'relev', 'driver', 'ftp', 'site', 'regard', 'simon', 'crow']]
# [['recent', 'got', 'file', 'describ', 'librari', 'render', 'routin', 'call', 'sipp', 'simpl', 'polygon', 'processor', 'could', 'anyon', 'tell', 'ftp', 'sourc', 'code', 'newest', 'version', 'around', 'also', 've', 'never', 'use', 'renderman', 'wonder', 'renderman', 'like', 'sipp', 'ie', 'librari', 'render', 'routin', 'one', 'use', 'make', 'program', 'creat', 'imag', 'thank', 'joe', 'thamjo', 'tham', 'jothersysedmontonabca'], ['hello', 'everybodi', 'use', 'pixar', 'renderman', 'three', 'scene', 'descript', 'languag', 'creat', 'three', 'world', 'pleas', 'help', 'use', 'renderman', 'librari', 'next', 'document', 'nextstep', 'version', 'renderman', 'avail', 'creat', 'complic', 'scene', 'render', 'use', 'surfac', 'shader', 'bring', 'life', 'appli', 'shadow', 'reflectionsa', 'far', 'understand', 'defin', 'environment', 'shadow', 'map', 'produc', 'reflect', 'shadow', 'know', 'use', 'themani', 'advis', 'simpl', 'rib', 'exampl', 'appreciatedthank', 'advancealex', 'kolesov', 'moscow', 'russiatalu', 'imag', 'commun', 'corporationemail', 'alextalusmsksu', 'next', 'mail', 'accept'], ['anybodi', 'know', 'good', 'two', 'dgraphic', 'packag', 'avail', 'ibm', 'rs', 'six', 'zero', 'zero', 'zero', 'aix', 'look', 'someth', 'like', 'dec', 'gk', 'hewlettpackard', 'starbas', 'reason', 'good', 'support', 'differ', 'output', 'devic', 'like', 'plotter', 'termin', 'etc', 'tri', 'also', 'xgk', 'one', 'one', 'distribut', 'ibm', 'implement', 'phig', 'work', 'requir', 'output', 'devic', 'xwindow', 'salesman', 'ibm', 'familiar', 'graphic', 'expect', 'good', 'solut', 'ari', 'ari', 'suutari', 'aricarelfi', 'carelcomp', 'oy', 'lappeenranta', 'finland'], ['requir', 'bgi', 'driver', 'super', 'vga', 'display', 'super', 'xvga', 'display', 'anyon', 'know', 'could', 'obtain', 'relev', 'driver', 'ftp', 'site', 'regard', 'simon', 'crow'], ['hi', 'immedi', 'need', 'detail', 'variou', 'graphic', 'compressiontechniqu', 'know', 'could', 'obtain', 'descript', 'algorithm', 'publicdomain', 'sourc', 'code', 'format', 'jpeg', 'gif', 'andfract', 'would', 'immens', 'grate', 'could', 'share', 'info', 'withm', 'project', 'contempl', 'doingthank', 'advanc', 'pleas', 'repli', 'via', 'email', 'possiblehbj']]
# [['recent', 'got', 'file', 'describ', 'librari', 'render', 'routin', 'call', 'sipp', 'simpl', 'polygon', 'processor', 'could', 'anyon', 'tell', 'ftp', 'sourc', 'code', 'newest', 'version', 'around', 'also', 've', 'never', 'use', 'renderman', 'wonder', 'renderman', 'like', 'sipp', 'ie', 'librari', 'render', 'routin', 'one', 'use', 'make', 'program', 'creat', 'imag', 'thank', 'joe', 'thamjo', 'tham', 'jothersysedmontonabca'], ['hello', 'everybodi', 'use', 'pixar', 'renderman', 'three', 'scene', 'descript', 'languag', 'creat', 'three', 'world', 'pleas', 'help', 'use', 'renderman', 'librari', 'next', 'document', 'nextstep', 'version', 'renderman', 'avail', 'creat', 'complic', 'scene', 'render', 'use', 'surfac', 'shader', 'bring', 'life', 'appli', 'shadow', 'reflectionsa', 'far', 'understand', 'defin', 'environment', 'shadow', 'map', 'produc', 'reflect', 'shadow', 'know', 'use', 'themani', 'advis', 'simpl', 'rib', 'exampl', 'appreciatedthank', 'advancealex', 'kolesov', 'moscow', 'russiatalu', 'imag', 'commun', 'corporationemail', 'alextalusmsksu', 'next', 'mail', 'accept'], ['anybodi', 'know', 'good', 'two', 'dgraphic', 'packag', 'avail', 'ibm', 'rs', 'six', 'zero', 'zero', 'zero', 'aix', 'look', 'someth', 'like', 'dec', 'gk', 'hewlettpackard', 'starbas', 'reason', 'good', 'support', 'differ', 'output', 'devic', 'like', 'plotter', 'termin', 'etc', 'tri', 'also', 'xgk', 'one', 'one', 'distribut', 'ibm', 'implement', 'phig', 'work', 'requir', 'output', 'devic', 'xwindow', 'salesman', 'ibm', 'familiar', 'graphic', 'expect', 'good', 'solut', 'ari', 'ari', 'suutari', 'aricarelfi', 'carelcomp', 'oy', 'lappeenranta', 'finland'], ['requir', 'bgi', 'driver', 'super', 'vga', 'display', 'super', 'xvga', 'display', 'anyon', 'know', 'could', 'obtain', 'relev', 'driver', 'ftp', 'site', 'regard', 'simon', 'crow'], ['hi', 'immedi', 'need', 'detail', 'variou', 'graphic', 'compressiontechniqu', 'know', 'could', 'obtain', 'descript', 'algorithm', 'publicdomain', 'sourc', 'code', 'format', 'jpeg', 'gif', 'andfract', 'would', 'immens', 'grate', 'could', 'share', 'info', 'withm', 'project', 'contempl', 'doingthank', 'advanc', 'pleas', 'repli', 'via', 'email', 'possiblehbj'], ['wgt', 'wordup', 'graphic', 'toolkit', 'design', 'truli', 'mycoprogramm', 'brother', 'chri', 'egert', 'turboborland', 'graphicslibrari', 'program', 'three', 'two', 'zero', 'two', 'zero', 'zero', 'two', 'five', 'six', 'vga', 'current', 'produc', 'assharewar', 'year', 'may', 'commerci', 'product', 'excus', 'typosther', 'backspac', 'termin', 'featur', 'includ', 'load', 'save', 'bitimag', 'call', 'block', 'herein', 'flip', 'resiz', 'warp', 'block', 'load', 'save', 'palett', 'fade', 'sever', 'memori', 'graphic', 'primit', 'line', 'circl', 'bar', 'rectangl', 'region', 'fill', 'usual', 'useless', 'floodfil', 'sprite', 'anim', 'bitmap', 'two', 'zero', 'zero', 'onscreen', 'joystickmous', 'support', 'sb', 'support', 'voc', 'cmf', 'tilebas', 'game', 'creation', 'use', 'one', 'six', 'one', 'six', 'pixel', 'tile', 'creat', 'three', 'two', 'zero', 'two', 'zero', 'zero', 'tile', 'map', 'game', 'world', 'like', 'duke', 'nuke', 'em', 'number', 'sprite', 'increas', 'one', 'zero', 'zero', 'zero', 'profession', 'sprite', 'creator', 'util', 'map', 'maker', 'routin', 'simplifi', 'scroll', 'game', 'use', 'map', 'etc', 'fli', 'play', 'routin', 'sprite', 'anim', 'fli', 'play', 'pcx', 'support', 'soon', 'gif', 'emsxm', 'come', 'soon', 'wellleav', 'email', 'barri', 'egert', 'egerterobelixgaulcsduwocafil', 'avail', 'use', 'mget', 'wgtzipsimtel', 'two', 'zero', 'mirror', 'pd', 'one', 'msdosturbocnicfunetfi', 'pubmsdosgamesprogrammingsom', 'site', 'may', 'recent', 'file', 'contact', 'info', 'regard', 'uptod', 'inform']]
# [['recent', 'got', 'file', 'describ', 'librari', 'render', 'routin', 'call', 'sipp', 'simpl', 'polygon', 'processor', 'could', 'anyon', 'tell', 'ftp', 'sourc', 'code', 'newest', 'version', 'around', 'also', 've', 'never', 'use', 'renderman', 'wonder', 'renderman', 'like', 'sipp', 'ie', 'librari', 'render', 'routin', 'one', 'use', 'make', 'program', 'creat', 'imag', 'thank', 'joe', 'thamjo', 'tham', 'jothersysedmontonabca'], ['hello', 'everybodi', 'use', 'pixar', 'renderman', 'three', 'scene', 'descript', 'languag', 'creat', 'three', 'world', 'pleas', 'help', 'use', 'renderman', 'librari', 'next', 'document', 'nextstep', 'version', 'renderman', 'avail', 'creat', 'complic', 'scene', 'render', 'use', 'surfac', 'shader', 'bring', 'life', 'appli', 'shadow', 'reflectionsa', 'far', 'understand', 'defin', 'environment', 'shadow', 'map', 'produc', 'reflect', 'shadow', 'know', 'use', 'themani', 'advis', 'simpl', 'rib', 'exampl', 'appreciatedthank', 'advancealex', 'kolesov', 'moscow', 'russiatalu', 'imag', 'commun', 'corporationemail', 'alextalusmsksu', 'next', 'mail', 'accept'], ['anybodi', 'know', 'good', 'two', 'dgraphic', 'packag', 'avail', 'ibm', 'rs', 'six', 'zero', 'zero', 'zero', 'aix', 'look', 'someth', 'like', 'dec', 'gk', 'hewlettpackard', 'starbas', 'reason', 'good', 'support', 'differ', 'output', 'devic', 'like', 'plotter', 'termin', 'etc', 'tri', 'also', 'xgk', 'one', 'one', 'distribut', 'ibm', 'implement', 'phig', 'work', 'requir', 'output', 'devic', 'xwindow', 'salesman', 'ibm', 'familiar', 'graphic', 'expect', 'good', 'solut', 'ari', 'ari', 'suutari', 'aricarelfi', 'carelcomp', 'oy', 'lappeenranta', 'finland'], ['requir', 'bgi', 'driver', 'super', 'vga', 'display', 'super', 'xvga', 'display', 'anyon', 'know', 'could', 'obtain', 'relev', 'driver', 'ftp', 'site', 'regard', 'simon', 'crow'], ['hi', 'immedi', 'need', 'detail', 'variou', 'graphic', 'compressiontechniqu', 'know', 'could', 'obtain', 'descript', 'algorithm', 'publicdomain', 'sourc', 'code', 'format', 'jpeg', 'gif', 'andfract', 'would', 'immens', 'grate', 'could', 'share', 'info', 'withm', 'project', 'contempl', 'doingthank', 'advanc', 'pleas', 'repli', 'via', 'email', 'possiblehbj'], ['wgt', 'wordup', 'graphic', 'toolkit', 'design', 'truli', 'mycoprogramm', 'brother', 'chri', 'egert', 'turboborland', 'graphicslibrari', 'program', 'three', 'two', 'zero', 'two', 'zero', 'zero', 'two', 'five', 'six', 'vga', 'current', 'produc', 'assharewar', 'year', 'may', 'commerci', 'product', 'excus', 'typosther', 'backspac', 'termin', 'featur', 'includ', 'load', 'save', 'bitimag', 'call', 'block', 'herein', 'flip', 'resiz', 'warp', 'block', 'load', 'save', 'palett', 'fade', 'sever', 'memori', 'graphic', 'primit', 'line', 'circl', 'bar', 'rectangl', 'region', 'fill', 'usual', 'useless', 'floodfil', 'sprite', 'anim', 'bitmap', 'two', 'zero', 'zero', 'onscreen', 'joystickmous', 'support', 'sb', 'support', 'voc', 'cmf', 'tilebas', 'game', 'creation', 'use', 'one', 'six', 'one', 'six', 'pixel', 'tile', 'creat', 'three', 'two', 'zero', 'two', 'zero', 'zero', 'tile', 'map', 'game', 'world', 'like', 'duke', 'nuke', 'em', 'number', 'sprite', 'increas', 'one', 'zero', 'zero', 'zero', 'profession', 'sprite', 'creator', 'util', 'map', 'maker', 'routin', 'simplifi', 'scroll', 'game', 'use', 'map', 'etc', 'fli', 'play', 'routin', 'sprite', 'anim', 'fli', 'play', 'pcx', 'support', 'soon', 'gif', 'emsxm', 'come', 'soon', 'wellleav', 'email', 'barri', 'egert', 'egerterobelixgaulcsduwocafil', 'avail', 'use', 'mget', 'wgtzipsimtel', 'two', 'zero', 'mirror', 'pd', 'one', 'msdosturbocnicfunetfi', 'pubmsdosgamesprogrammingsom', 'site', 'may', 'recent', 'file', 'contact', 'info', 'regard', 'uptod', 'inform'], ['sorri', 'genoa', 'card', 'noth', 'ati', 'ultra', 'plu', 'two', 'mbca', 'nt', 'plu', 'ati', 'cost', 'three', 'three', 'zero', 'us', 'street', 'price']]
# [['recent', 'got', 'file', 'describ', 'librari', 'render', 'routin', 'call', 'sipp', 'simpl', 'polygon', 'processor', 'could', 'anyon', 'tell', 'ftp', 'sourc', 'code', 'newest', 'version', 'around', 'also', 've', 'never', 'use', 'renderman', 'wonder', 'renderman', 'like', 'sipp', 'ie', 'librari', 'render', 'routin', 'one', 'use', 'make', 'program', 'creat', 'imag', 'thank', 'joe', 'thamjo', 'tham', 'jothersysedmontonabca'], ['hello', 'everybodi', 'use', 'pixar', 'renderman', 'three', 'scene', 'descript', 'languag', 'creat', 'three', 'world', 'pleas', 'help', 'use', 'renderman', 'librari', 'next', 'document', 'nextstep', 'version', 'renderman', 'avail', 'creat', 'complic', 'scene', 'render', 'use', 'surfac', 'shader', 'bring', 'life', 'appli', 'shadow', 'reflectionsa', 'far', 'understand', 'defin', 'environment', 'shadow', 'map', 'produc', 'reflect', 'shadow', 'know', 'use', 'themani', 'advis', 'simpl', 'rib', 'exampl', 'appreciatedthank', 'advancealex', 'kolesov', 'moscow', 'russiatalu', 'imag', 'commun', 'corporationemail', 'alextalusmsksu', 'next', 'mail', 'accept'], ['anybodi', 'know', 'good', 'two', 'dgraphic', 'packag', 'avail', 'ibm', 'rs', 'six', 'zero', 'zero', 'zero', 'aix', 'look', 'someth', 'like', 'dec', 'gk', 'hewlettpackard', 'starbas', 'reason', 'good', 'support', 'differ', 'output', 'devic', 'like', 'plotter', 'termin', 'etc', 'tri', 'also', 'xgk', 'one', 'one', 'distribut', 'ibm', 'implement', 'phig', 'work', 'requir', 'output', 'devic', 'xwindow', 'salesman', 'ibm', 'familiar', 'graphic', 'expect', 'good', 'solut', 'ari', 'ari', 'suutari', 'aricarelfi', 'carelcomp', 'oy', 'lappeenranta', 'finland'], ['requir', 'bgi', 'driver', 'super', 'vga', 'display', 'super', 'xvga', 'display', 'anyon', 'know', 'could', 'obtain', 'relev', 'driver', 'ftp', 'site', 'regard', 'simon', 'crow'], ['hi', 'immedi', 'need', 'detail', 'variou', 'graphic', 'compressiontechniqu', 'know', 'could', 'obtain', 'descript', 'algorithm', 'publicdomain', 'sourc', 'code', 'format', 'jpeg', 'gif', 'andfract', 'would', 'immens', 'grate', 'could', 'share', 'info', 'withm', 'project', 'contempl', 'doingthank', 'advanc', 'pleas', 'repli', 'via', 'email', 'possiblehbj'], ['wgt', 'wordup', 'graphic', 'toolkit', 'design', 'truli', 'mycoprogramm', 'brother', 'chri', 'egert', 'turboborland', 'graphicslibrari', 'program', 'three', 'two', 'zero', 'two', 'zero', 'zero', 'two', 'five', 'six', 'vga', 'current', 'produc', 'assharewar', 'year', 'may', 'commerci', 'product', 'excus', 'typosther', 'backspac', 'termin', 'featur', 'includ', 'load', 'save', 'bitimag', 'call', 'block', 'herein', 'flip', 'resiz', 'warp', 'block', 'load', 'save', 'palett', 'fade', 'sever', 'memori', 'graphic', 'primit', 'line', 'circl', 'bar', 'rectangl', 'region', 'fill', 'usual', 'useless', 'floodfil', 'sprite', 'anim', 'bitmap', 'two', 'zero', 'zero', 'onscreen', 'joystickmous', 'support', 'sb', 'support', 'voc', 'cmf', 'tilebas', 'game', 'creation', 'use', 'one', 'six', 'one', 'six', 'pixel', 'tile', 'creat', 'three', 'two', 'zero', 'two', 'zero', 'zero', 'tile', 'map', 'game', 'world', 'like', 'duke', 'nuke', 'em', 'number', 'sprite', 'increas', 'one', 'zero', 'zero', 'zero', 'profession', 'sprite', 'creator', 'util', 'map', 'maker', 'routin', 'simplifi', 'scroll', 'game', 'use', 'map', 'etc', 'fli', 'play', 'routin', 'sprite', 'anim', 'fli', 'play', 'pcx', 'support', 'soon', 'gif', 'emsxm', 'come', 'soon', 'wellleav', 'email', 'barri', 'egert', 'egerterobelixgaulcsduwocafil', 'avail', 'use', 'mget', 'wgtzipsimtel', 'two', 'zero', 'mirror', 'pd', 'one', 'msdosturbocnicfunetfi', 'pubmsdosgamesprogrammingsom', 'site', 'may', 'recent', 'file', 'contact', 'info', 'regard', 'uptod', 'inform'], ['sorri', 'genoa', 'card', 'noth', 'ati', 'ultra', 'plu', 'two', 'mbca', 'nt', 'plu', 'ati', 'cost', 'three', 'three', 'zero', 'us', 'street', 'price'], ['write', 'utili', 'convert', 'regi', 'tekton', 'esacp', 'sequenc', 'use', 'format', 'would', 'rather', 'goto', 'bitmap', 'format', 'convert',  ...
# [['recent', 'got', 'file', 'describ', 'librari', 'render', 'routin', 'call', 'sipp', 'simpl', 'polygon', 'processor', 'could', 'anyon', 'tell', 'ftp', 'sourc', 'code', 'newest', 'version', 'around', 'also', 've', 'never', 'use', 'renderman', 'wonder', 'renderman', 'like', 'sipp', 'ie', 'librari', 'render', 'routin', 'one', 'use', 'make', 'program', 'creat', 'imag', 'thank', 'joe', 'thamjo', 'tham', 'jothersysedmontonabca'], ['hello', 'everybodi', 'use', 'pixar', 'renderman', 'three', 'scene', 'descript', 'languag', 'creat', 'three', 'world', 'pleas', 'help', 'use', 'renderman', 'librari', 'next', 'document', 'nextstep', 'version', 'renderman', 'avail', 'creat', 'complic', 'scene', 'render', 'use', 'surfac', 'shader', 'bring', 'life', 'appli', 'shadow', 'reflectionsa', 'far', 'understand', 'defin', 'environment', 'shadow', 'map', 'produc', 'reflect', 'shadow', 'know', 'use', 'themani', 'advis', 'simpl', 'rib', 'exampl', 'appreciatedthank', 'advancealex', 'kolesov', 'moscow', 'russiatalu', 'imag', 'commun', 'corporationemail', 'alextalusmsksu', 'next', 'mail', 'accept'], ['anybodi', 'know', 'good', 'two', 'dgraphic', 'packag', 'avail', 'ibm', 'rs', 'six', 'zero', 'zero', 'zero', 'aix', 'look', 'someth', 'like', 'dec', 'gk', 'hewlettpackard', 'starbas', 'reason', 'good', 'support', 'differ', 'output', 'devic', 'like', 'plotter', 'termin', 'etc', 'tri', 'also', 'xgk', 'one', 'one', 'distribut', 'ibm', 'implement', 'phig', 'work', 'requir', 'output', 'devic', 'xwindow', 'salesman', 'ibm', 'familiar', 'graphic', 'expect', 'good', 'solut', 'ari', 'ari', 'suutari', 'aricarelfi', 'carelcomp', 'oy', 'lappeenranta', 'finland'], ['requir', 'bgi', 'driver', 'super', 'vga', 'display', 'super', 'xvga', 'display', 'anyon', 'know', 'could', 'obtain', 'relev', 'driver', 'ftp', 'site', 'regard', 'simon', 'crow'], ['hi', 'immedi', 'need', 'detail', 'variou', 'graphic', 'compressiontechniqu', 'know', 'could', 'obtain', 'descript', 'algorithm', 'publicdomain', 'sourc', 'code', 'format', 'jpeg', 'gif', 'andfract', 'would', 'immens', 'grate', 'could', 'share', 'info', 'withm', 'project', 'contempl', 'doingthank', 'advanc', 'pleas', 'repli', 'via', 'email', 'possiblehbj'], ['wgt', 'wordup', 'graphic', 'toolkit', 'design', 'truli', 'mycoprogramm', 'brother', 'chri', 'egert', 'turboborland', 'graphicslibrari', 'program', 'three', 'two', 'zero', 'two', 'zero', 'zero', 'two', 'five', 'six', 'vga', 'current', 'produc', 'assharewar', 'year', 'may', 'commerci', 'product', 'excus', 'typosther', 'backspac', 'termin', 'featur', 'includ', 'load', 'save', 'bitimag', 'call', 'block', 'herein', 'flip', 'resiz', 'warp', 'block', 'load', 'save', 'palett', 'fade', 'sever', 'memori', 'graphic', 'primit', 'line', 'circl', 'bar', 'rectangl', 'region', 'fill', 'usual', 'useless', 'floodfil', 'sprite', 'anim', 'bitmap', 'two', 'zero', 'zero', 'onscreen', 'joystickmous', 'support', 'sb', 'support', 'voc', 'cmf', 'tilebas', 'game', 'creation', 'use', 'one', 'six', 'one', 'six', 'pixel', 'tile', 'creat', 'three', 'two', 'zero', 'two', 'zero', 'zero', 'tile', 'map', 'game', 'world', 'like', 'duke', 'nuke', 'em', 'number', 'sprite', 'increas', 'one', 'zero', 'zero', 'zero', 'profession', 'sprite', 'creator', 'util', 'map', 'maker', 'routin', 'simplifi', 'scroll', 'game', 'use', 'map', 'etc', 'fli', 'play', 'routin', 'sprite', 'anim', 'fli', 'play', 'pcx', 'support', 'soon', 'gif', 'emsxm', 'come', 'soon', 'wellleav', 'email', 'barri', 'egert', 'egerterobelixgaulcsduwocafil', 'avail', 'use', 'mget', 'wgtzipsimtel', 'two', 'zero', 'mirror', 'pd', 'one', 'msdosturbocnicfunetfi', 'pubmsdosgamesprogrammingsom', 'site', 'may', 'recent', 'file', 'contact', 'info', 'regard', 'uptod', 'inform'], ['sorri', 'genoa', 'card', 'noth', 'ati', 'ultra', 'plu', 'two', 'mbca', 'nt', 'plu', 'ati', 'cost', 'three', 'three', 'zero', 'us', 'street', 'price'], ['write', 'utili', 'convert', 'regi', 'tekton', 'esacp', 'sequenc', 'use', 'format', 'would', 'rather', 'goto', 'bitmap', 'format', 'convert',  ...
# [['recent', 'got', 'file', 'describ', 'librari', 'render', 'routin', 'call', 'sipp', 'simpl', 'polygon', 'processor', 'could', 'anyon', 'tell', 'ftp', 'sourc', 'code', 'newest', 'version', 'around', 'also', 've', 'never', 'use', 'renderman', 'wonder', 'renderman', 'like', 'sipp', 'ie', 'librari', 'render', 'routin', 'one', 'use', 'make', 'program', 'creat', 'imag', 'thank', 'joe', 'thamjo', 'tham', 'jothersysedmontonabca'], ['hello', 'everybodi', 'use', 'pixar', 'renderman', 'three', 'scene', 'descript', 'languag', 'creat', 'three', 'world', 'pleas', 'help', 'use', 'renderman', 'librari', 'next', 'document', 'nextstep', 'version', 'renderman', 'avail', 'creat', 'complic', 'scene', 'render', 'use', 'surfac', 'shader', 'bring', 'life', 'appli', 'shadow', 'reflectionsa', 'far', 'understand', 'defin', 'environment', 'shadow', 'map', 'produc', 'reflect', 'shadow', 'know', 'use', 'themani', 'advis', 'simpl', 'rib', 'exampl', 'appreciatedthank', 'advancealex', 'kolesov', 'moscow', 'russiatalu', 'imag', 'commun', 'corporationemail', 'alextalusmsksu', 'next', 'mail', 'accept'], ['anybodi', 'know', 'good', 'two', 'dgraphic', 'packag', 'avail', 'ibm', 'rs', 'six', 'zero', 'zero', 'zero', 'aix', 'look', 'someth', 'like', 'dec', 'gk', 'hewlettpackard', 'starbas', 'reason', 'good', 'support', 'differ', 'output', 'devic', 'like', 'plotter', 'termin', 'etc', 'tri', 'also', 'xgk', 'one', 'one', 'distribut', 'ibm', 'implement', 'phig', 'work', 'requir', 'output', 'devic', 'xwindow', 'salesman', 'ibm', 'familiar', 'graphic', 'expect', 'good', 'solut', 'ari', 'ari', 'suutari', 'aricarelfi', 'carelcomp', 'oy', 'lappeenranta', 'finland'], ['requir', 'bgi', 'driver', 'super', 'vga', 'display', 'super', 'xvga', 'display', 'anyon', 'know', 'could', 'obtain', 'relev', 'driver', 'ftp', 'site', 'regard', 'simon', 'crow'], ['hi', 'immedi', 'need', 'detail', 'variou', 'graphic', 'compressiontechniqu', 'know', 'could', 'obtain', 'descript', 'algorithm', 'publicdomain', 'sourc', 'code', 'format', 'jpeg', 'gif', 'andfract', 'would', 'immens', 'grate', 'could', 'share', 'info', 'withm', 'project', 'contempl', 'doingthank', 'advanc', 'pleas', 'repli', 'via', 'email', 'possiblehbj'], ['wgt', 'wordup', 'graphic', 'toolkit', 'design', 'truli', 'mycoprogramm', 'brother', 'chri', 'egert', 'turboborland', 'graphicslibrari', 'program', 'three', 'two', 'zero', 'two', 'zero', 'zero', 'two', 'five', 'six', 'vga', 'current', 'produc', 'assharewar', 'year', 'may', 'commerci', 'product', 'excus', 'typosther', 'backspac', 'termin', 'featur', 'includ', 'load', 'save', 'bitimag', 'call', 'block', 'herein', 'flip', 'resiz', 'warp', 'block', 'load', 'save', 'palett', 'fade', 'sever', 'memori', 'graphic', 'primit', 'line', 'circl', 'bar', 'rectangl', 'region', 'fill', 'usual', 'useless', 'floodfil', 'sprite', 'anim', 'bitmap', 'two', 'zero', 'zero', 'onscreen', 'joystickmous', 'support', 'sb', 'support', 'voc', 'cmf', 'tilebas', 'game', 'creation', 'use', 'one', 'six', 'one', 'six', 'pixel', 'tile', 'creat', 'three', 'two', 'zero', 'two', 'zero', 'zero', 'tile', 'map', 'game', 'world', 'like', 'duke', 'nuke', 'em', 'number', 'sprite', 'increas', 'one', 'zero', 'zero', 'zero', 'profession', 'sprite', 'creator', 'util', 'map', 'maker', 'routin', 'simplifi', 'scroll', 'game', 'use', 'map', 'etc', 'fli', 'play', 'routin', 'sprite', 'anim', 'fli', 'play', 'pcx', 'support', 'soon', 'gif', 'emsxm', 'come', 'soon', 'wellleav', 'email', 'barri', 'egert', 'egerterobelixgaulcsduwocafil', 'avail', 'use', 'mget', 'wgtzipsimtel', 'two', 'zero', 'mirror', 'pd', 'one', 'msdosturbocnicfunetfi', 'pubmsdosgamesprogrammingsom', 'site', 'may', 'recent', 'file', 'contact', 'info', 'regard', 'uptod', 'inform'], ['sorri', 'genoa', 'card', 'noth', 'ati', 'ultra', 'plu', 'two', 'mbca', 'nt', 'plu', 'ati', 'cost', 'three', 'three', 'zero', 'us', 'street', 'price'], ['write', 'utili', 'convert', 'regi', 'tekton', 'esacp', 'sequenc', 'use', 'format', 'would', 'rather', 'goto', 'bitmap', 'format', 'convert',  ...
# [['recent', 'got', 'file', 'describ', 'librari', 'render', 'routin', 'call', 'sipp', 'simpl', 'polygon', 'processor', 'could', 'anyon', 'tell', 'ftp', 'sourc', 'code', 'newest', 'version', 'around', 'also', 've', 'never', 'use', 'renderman', 'wonder', 'renderman', 'like', 'sipp', 'ie', 'librari', 'render', 'routin', 'one', 'use', 'make', 'program', 'creat', 'imag', 'thank', 'joe', 'thamjo', 'tham', 'jothersysedmontonabca'], ['hello', 'everybodi', 'use', 'pixar', 'renderman', 'three', 'scene', 'descript', 'languag', 'creat', 'three', 'world', 'pleas', 'help', 'use', 'renderman', 'librari', 'next', 'document', 'nextstep', 'version', 'renderman', 'avail', 'creat', 'complic', 'scene', 'render', 'use', 'surfac', 'shader', 'bring', 'life', 'appli', 'shadow', 'reflectionsa', 'far', 'understand', 'defin', 'environment', 'shadow', 'map', 'produc', 'reflect', 'shadow', 'know', 'use', 'themani', 'advis', 'simpl', 'rib', 'exampl', 'appreciatedthank', 'advancealex', 'kolesov', 'moscow', 'russiatalu', 'imag', 'commun', 'corporationemail', 'alextalusmsksu', 'next', 'mail', 'accept'], ['anybodi', 'know', 'good', 'two', 'dgraphic', 'packag', 'avail', 'ibm', 'rs', 'six', 'zero', 'zero', 'zero', 'aix', 'look', 'someth', 'like', 'dec', 'gk', 'hewlettpackard', 'starbas', 'reason', 'good', 'support', 'differ', 'output', 'devic', 'like', 'plotter', 'termin', 'etc', 'tri', 'also', 'xgk', 'one', 'one', 'distribut', 'ibm', 'implement', 'phig', 'work', 'requir', 'output', 'devic', 'xwindow', 'salesman', 'ibm', 'familiar', 'graphic', 'expect', 'good', 'solut', 'ari', 'ari', 'suutari', 'aricarelfi', 'carelcomp', 'oy', 'lappeenranta', 'finland'], ['requir', 'bgi', 'driver', 'super', 'vga', 'display', 'super', 'xvga', 'display', 'anyon', 'know', 'could', 'obtain', 'relev', 'driver', 'ftp', 'site', 'regard', 'simon', 'crow'], ['hi', 'immedi', 'need', 'detail', 'variou', 'graphic', 'compressiontechniqu', 'know', 'could', 'obtain', 'descript', 'algorithm', 'publicdomain', 'sourc', 'code', 'format', 'jpeg', 'gif', 'andfract', 'would', 'immens', 'grate', 'could', 'share', 'info', 'withm', 'project', 'contempl', 'doingthank', 'advanc', 'pleas', 'repli', 'via', 'email', 'possiblehbj'], ['wgt', 'wordup', 'graphic', 'toolkit', 'design', 'truli', 'mycoprogramm', 'brother', 'chri', 'egert', 'turboborland', 'graphicslibrari', 'program', 'three', 'two', 'zero', 'two', 'zero', 'zero', 'two', 'five', 'six', 'vga', 'current', 'produc', 'assharewar', 'year', 'may', 'commerci', 'product', 'excus', 'typosther', 'backspac', 'termin', 'featur', 'includ', 'load', 'save', 'bitimag', 'call', 'block', 'herein', 'flip', 'resiz', 'warp', 'block', 'load', 'save', 'palett', 'fade', 'sever', 'memori', 'graphic', 'primit', 'line', 'circl', 'bar', 'rectangl', 'region', 'fill', 'usual', 'useless', 'floodfil', 'sprite', 'anim', 'bitmap', 'two', 'zero', 'zero', 'onscreen', 'joystickmous', 'support', 'sb', 'support', 'voc', 'cmf', 'tilebas', 'game', 'creation', 'use', 'one', 'six', 'one', 'six', 'pixel', 'tile', 'creat', 'three', 'two', 'zero', 'two', 'zero', 'zero', 'tile', 'map', 'game', 'world', 'like', 'duke', 'nuke', 'em', 'number', 'sprite', 'increas', 'one', 'zero', 'zero', 'zero', 'profession', 'sprite', 'creator', 'util', 'map', 'maker', 'routin', 'simplifi', 'scroll', 'game', 'use', 'map', 'etc', 'fli', 'play', 'routin', 'sprite', 'anim', 'fli', 'play', 'pcx', 'support', 'soon', 'gif', 'emsxm', 'come', 'soon', 'wellleav', 'email', 'barri', 'egert', 'egerterobelixgaulcsduwocafil', 'avail', 'use', 'mget', 'wgtzipsimtel', 'two', 'zero', 'mirror', 'pd', 'one', 'msdosturbocnicfunetfi', 'pubmsdosgamesprogrammingsom', 'site', 'may', 'recent', 'file', 'contact', 'info', 'regard', 'uptod', 'inform'], ['sorri', 'genoa', 'card', 'noth', 'ati', 'ultra', 'plu', 'two', 'mbca', 'nt', 'plu', 'ati', 'cost', 'three', 'three', 'zero', 'us', 'street', 'price'], ['write', 'utili', 'convert', 'regi', 'tekton', 'esacp', 'sequenc', 'use', 'format', 'would', 'rather', 'goto', 'bitmap', 'format', 'convert',  ...
# [['recent', 'got', 'file', 'describ', 'librari', 'render', 'routin', 'call', 'sipp', 'simpl', 'polygon', 'processor', 'could', 'anyon', 'tell', 'ftp', 'sourc', 'code', 'newest', 'version', 'around', 'also', 've', 'never', 'use', 'renderman', 'wonder', 'renderman', 'like', 'sipp', 'ie', 'librari', 'render', 'routin', 'one', 'use', 'make', 'program', 'creat', 'imag', 'thank', 'joe', 'thamjo', 'tham', 'jothersysedmontonabca'], ['hello', 'everybodi', 'use', 'pixar', 'renderman', 'three', 'scene', 'descript', 'languag', 'creat', 'three', 'world', 'pleas', 'help', 'use', 'renderman', 'librari', 'next', 'document', 'nextstep', 'version', 'renderman', 'avail', 'creat', 'complic', 'scene', 'render', 'use', 'surfac', 'shader', 'bring', 'life', 'appli', 'shadow', 'reflectionsa', 'far', 'understand', 'defin', 'environment', 'shadow', 'map', 'produc', 'reflect', 'shadow', 'know', 'use', 'themani', 'advis', 'simpl', 'rib', 'exampl', 'appreciatedthank', 'advancealex', 'kolesov', 'moscow', 'russiatalu', 'imag', 'commun', 'corporationemail', 'alextalusmsksu', 'next', 'mail', 'accept'], ['anybodi', 'know', 'good', 'two', 'dgraphic', 'packag', 'avail', 'ibm', 'rs', 'six', 'zero', 'zero', 'zero', 'aix', 'look', 'someth', 'like', 'dec', 'gk', 'hewlettpackard', 'starbas', 'reason', 'good', 'support', 'differ', 'output', 'devic', 'like', 'plotter', 'termin', 'etc', 'tri', 'also', 'xgk', 'one', 'one', 'distribut', 'ibm', 'implement', 'phig', 'work', 'requir', 'output', 'devic', 'xwindow', 'salesman', 'ibm', 'familiar', 'graphic', 'expect', 'good', 'solut', 'ari', 'ari', 'suutari', 'aricarelfi', 'carelcomp', 'oy', 'lappeenranta', 'finland'], ['requir', 'bgi', 'driver', 'super', 'vga', 'display', 'super', 'xvga', 'display', 'anyon', 'know', 'could', 'obtain', 'relev', 'driver', 'ftp', 'site', 'regard', 'simon', 'crow'], ['hi', 'immedi', 'need', 'detail', 'variou', 'graphic', 'compressiontechniqu', 'know', 'could', 'obtain', 'descript', 'algorithm', 'publicdomain', 'sourc', 'code', 'format', 'jpeg', 'gif', 'andfract', 'would', 'immens', 'grate', 'could', 'share', 'info', 'withm', 'project', 'contempl', 'doingthank', 'advanc', 'pleas', 'repli', 'via', 'email', 'possiblehbj'], ['wgt', 'wordup', 'graphic', 'toolkit', 'design', 'truli', 'mycoprogramm', 'brother', 'chri', 'egert', 'turboborland', 'graphicslibrari', 'program', 'three', 'two', 'zero', 'two', 'zero', 'zero', 'two', 'five', 'six', 'vga', 'current', 'produc', 'assharewar', 'year', 'may', 'commerci', 'product', 'excus', 'typosther', 'backspac', 'termin', 'featur', 'includ', 'load', 'save', 'bitimag', 'call', 'block', 'herein', 'flip', 'resiz', 'warp', 'block', 'load', 'save', 'palett', 'fade', 'sever', 'memori', 'graphic', 'primit', 'line', 'circl', 'bar', 'rectangl', 'region', 'fill', 'usual', 'useless', 'floodfil', 'sprite', 'anim', 'bitmap', 'two', 'zero', 'zero', 'onscreen', 'joystickmous', 'support', 'sb', 'support', 'voc', 'cmf', 'tilebas', 'game', 'creation', 'use', 'one', 'six', 'one', 'six', 'pixel', 'tile', 'creat', 'three', 'two', 'zero', 'two', 'zero', 'zero', 'tile', 'map', 'game', 'world', 'like', 'duke', 'nuke', 'em', 'number', 'sprite', 'increas', 'one', 'zero', 'zero', 'zero', 'profession', 'sprite', 'creator', 'util', 'map', 'maker', 'routin', 'simplifi', 'scroll', 'game', 'use', 'map', 'etc', 'fli', 'play', 'routin', 'sprite', 'anim', 'fli', 'play', 'pcx', 'support', 'soon', 'gif', 'emsxm', 'come', 'soon', 'wellleav', 'email', 'barri', 'egert', 'egerterobelixgaulcsduwocafil', 'avail', 'use', 'mget', 'wgtzipsimtel', 'two', 'zero', 'mirror', 'pd', 'one', 'msdosturbocnicfunetfi', 'pubmsdosgamesprogrammingsom', 'site', 'may', 'recent', 'file', 'contact', 'info', 'regard', 'uptod', 'inform'], ['sorri', 'genoa', 'card', 'noth', 'ati', 'ultra', 'plu', 'two', 'mbca', 'nt', 'plu', 'ati', 'cost', 'three', 'three', 'zero', 'us', 'street', 'price'], ['write', 'utili', 'convert', 'regi', 'tekton', 'esacp', 'sequenc', 'use', 'format', 'would', 'rather', 'goto', 'bitmap', 'format', 'convert',  ...
# [['recent', 'got', 'file', 'describ', 'librari', 'render', 'routin', 'call', 'sipp', 'simpl', 'polygon', 'processor', 'could', 'anyon', 'tell', 'ftp', 'sourc', 'code', 'newest', 'version', 'around', 'also', 've', 'never', 'use', 'renderman', 'wonder', 'renderman', 'like', 'sipp', 'ie', 'librari', 'render', 'routin', 'one', 'use', 'make', 'program', 'creat', 'imag', 'thank', 'joe', 'thamjo', 'tham', 'jothersysedmontonabca'], ['hello', 'everybodi', 'use', 'pixar', 'renderman', 'three', 'scene', 'descript', 'languag', 'creat', 'three', 'world', 'pleas', 'help', 'use', 'renderman', 'librari', 'next', 'document', 'nextstep', 'version', 'renderman', 'avail', 'creat', 'complic', 'scene', 'render', 'use', 'surfac', 'shader', 'bring', 'life', 'appli', 'shadow', 'reflectionsa', 'far', 'understand', 'defin', 'environment', 'shadow', 'map', 'produc', 'reflect', 'shadow', 'know', 'use', 'themani', 'advis', 'simpl', 'rib', 'exampl', 'appreciatedthank', 'advancealex', 'kolesov', 'moscow', 'russiatalu', 'imag', 'commun', 'corporationemail', 'alextalusmsksu', 'next', 'mail', 'accept'], ['anybodi', 'know', 'good', 'two', 'dgraphic', 'packag', 'avail', 'ibm', 'rs', 'six', 'zero', 'zero', 'zero', 'aix', 'look', 'someth', 'like', 'dec', 'gk', 'hewlettpackard', 'starbas', 'reason', 'good', 'support', 'differ', 'output', 'devic', 'like', 'plotter', 'termin', 'etc', 'tri', 'also', 'xgk', 'one', 'one', 'distribut', 'ibm', 'implement', 'phig', 'work', 'requir', 'output', 'devic', 'xwindow', 'salesman', 'ibm', 'familiar', 'graphic', 'expect', 'good', 'solut', 'ari', 'ari', 'suutari', 'aricarelfi', 'carelcomp', 'oy', 'lappeenranta', 'finland'], ['requir', 'bgi', 'driver', 'super', 'vga', 'display', 'super', 'xvga', 'display', 'anyon', 'know', 'could', 'obtain', 'relev', 'driver', 'ftp', 'site', 'regard', 'simon', 'crow'], ['hi', 'immedi', 'need', 'detail', 'variou', 'graphic', 'compressiontechniqu', 'know', 'could', 'obtain', 'descript', 'algorithm', 'publicdomain', 'sourc', 'code', 'format', 'jpeg', 'gif', 'andfract', 'would', 'immens', 'grate', 'could', 'share', 'info', 'withm', 'project', 'contempl', 'doingthank', 'advanc', 'pleas', 'repli', 'via', 'email', 'possiblehbj'], ['wgt', 'wordup', 'graphic', 'toolkit', 'design', 'truli', 'mycoprogramm', 'brother', 'chri', 'egert', 'turboborland', 'graphicslibrari', 'program', 'three', 'two', 'zero', 'two', 'zero', 'zero', 'two', 'five', 'six', 'vga', 'current', 'produc', 'assharewar', 'year', 'may', 'commerci', 'product', 'excus', 'typosther', 'backspac', 'termin', 'featur', 'includ', 'load', 'save', 'bitimag', 'call', 'block', 'herein', 'flip', 'resiz', 'warp', 'block', 'load', 'save', 'palett', 'fade', 'sever', 'memori', 'graphic', 'primit', 'line', 'circl', 'bar', 'rectangl', 'region', 'fill', 'usual', 'useless', 'floodfil', 'sprite', 'anim', 'bitmap', 'two', 'zero', 'zero', 'onscreen', 'joystickmous', 'support', 'sb', 'support', 'voc', 'cmf', 'tilebas', 'game', 'creation', 'use', 'one', 'six', 'one', 'six', 'pixel', 'tile', 'creat', 'three', 'two', 'zero', 'two', 'zero', 'zero', 'tile', 'map', 'game', 'world', 'like', 'duke', 'nuke', 'em', 'number', 'sprite', 'increas', 'one', 'zero', 'zero', 'zero', 'profession', 'sprite', 'creator', 'util', 'map', 'maker', 'routin', 'simplifi', 'scroll', 'game', 'use', 'map', 'etc', 'fli', 'play', 'routin', 'sprite', 'anim', 'fli', 'play', 'pcx', 'support', 'soon', 'gif', 'emsxm', 'come', 'soon', 'wellleav', 'email', 'barri', 'egert', 'egerterobelixgaulcsduwocafil', 'avail', 'use', 'mget', 'wgtzipsimtel', 'two', 'zero', 'mirror', 'pd', 'one', 'msdosturbocnicfunetfi', 'pubmsdosgamesprogrammingsom', 'site', 'may', 'recent', 'file', 'contact', 'info', 'regard', 'uptod', 'inform'], ['sorri', 'genoa', 'card', 'noth', 'ati', 'ultra', 'plu', 'two', 'mbca', 'nt', 'plu', 'ati', 'cost', 'three', 'three', 'zero', 'us', 'street', 'price'], ['write', 'utili', 'convert', 'regi', 'tekton', 'esacp', 'sequenc', 'use', 'format', 'would', 'rather', 'goto', 'bitmap', 'format', 'convert',  ...
# [['recent', 'got', 'file', 'describ', 'librari', 'render', 'routin', 'call', 'sipp', 'simpl', 'polygon', 'processor', 'could', 'anyon', 'tell', 'ftp', 'sourc', 'code', 'newest', 'version', 'around', 'also', 've', 'never', 'use', 'renderman', 'wonder', 'renderman', 'like', 'sipp', 'ie', 'librari', 'render', 'routin', 'one', 'use', 'make', 'program', 'creat', 'imag', 'thank', 'joe', 'thamjo', 'tham', 'jothersysedmontonabca'], ['hello', 'everybodi', 'use', 'pixar', 'renderman', 'three', 'scene', 'descript', 'languag', 'creat', 'three', 'world', 'pleas', 'help', 'use', 'renderman', 'librari', 'next', 'document', 'nextstep', 'version', 'renderman', 'avail', 'creat', 'complic', 'scene', 'render', 'use', 'surfac', 'shader', 'bring', 'life', 'appli', 'shadow', 'reflectionsa', 'far', 'understand', 'defin', 'environment', 'shadow', 'map', 'produc', 'reflect', 'shadow', 'know', 'use', 'themani', 'advis', 'simpl', 'rib', 'exampl', 'appreciatedthank', 'advancealex', 'kolesov', 'moscow', 'russiatalu', 'imag', 'commun', 'corporationemail', 'alextalusmsksu', 'next', 'mail', 'accept'], ['anybodi', 'know', 'good', 'two', 'dgraphic', 'packag', 'avail', 'ibm', 'rs', 'six', 'zero', 'zero', 'zero', 'aix', 'look', 'someth', 'like', 'dec', 'gk', 'hewlettpackard', 'starbas', 'reason', 'good', 'support', 'differ', 'output', 'devic', 'like', 'plotter', 'termin', 'etc', 'tri', 'also', 'xgk', 'one', 'one', 'distribut', 'ibm', 'implement', 'phig', 'work', 'requir', 'output', 'devic', 'xwindow', 'salesman', 'ibm', 'familiar', 'graphic', 'expect', 'good', 'solut', 'ari', 'ari', 'suutari', 'aricarelfi', 'carelcomp', 'oy', 'lappeenranta', 'finland'], ['requir', 'bgi', 'driver', 'super', 'vga', 'display', 'super', 'xvga', 'display', 'anyon', 'know', 'could', 'obtain', 'relev', 'driver', 'ftp', 'site', 'regard', 'simon', 'crow'], ['hi', 'immedi', 'need', 'detail', 'variou', 'graphic', 'compressiontechniqu', 'know', 'could', 'obtain', 'descript', 'algorithm', 'publicdomain', 'sourc', 'code', 'format', 'jpeg', 'gif', 'andfract', 'would', 'immens', 'grate', 'could', 'share', 'info', 'withm', 'project', 'contempl', 'doingthank', 'advanc', 'pleas', 'repli', 'via', 'email', 'possiblehbj'], ['wgt', 'wordup', 'graphic', 'toolkit', 'design', 'truli', 'mycoprogramm', 'brother', 'chri', 'egert', 'turboborland', 'graphicslibrari', 'program', 'three', 'two', 'zero', 'two', 'zero', 'zero', 'two', 'five', 'six', 'vga', 'current', 'produc', 'assharewar', 'year', 'may', 'commerci', 'product', 'excus', 'typosther', 'backspac', 'termin', 'featur', 'includ', 'load', 'save', 'bitimag', 'call', 'block', 'herein', 'flip', 'resiz', 'warp', 'block', 'load', 'save', 'palett', 'fade', 'sever', 'memori', 'graphic', 'primit', 'line', 'circl', 'bar', 'rectangl', 'region', 'fill', 'usual', 'useless', 'floodfil', 'sprite', 'anim', 'bitmap', 'two', 'zero', 'zero', 'onscreen', 'joystickmous', 'support', 'sb', 'support', 'voc', 'cmf', 'tilebas', 'game', 'creation', 'use', 'one', 'six', 'one', 'six', 'pixel', 'tile', 'creat', 'three', 'two', 'zero', 'two', 'zero', 'zero', 'tile', 'map', 'game', 'world', 'like', 'duke', 'nuke', 'em', 'number', 'sprite', 'increas', 'one', 'zero', 'zero', 'zero', 'profession', 'sprite', 'creator', 'util', 'map', 'maker', 'routin', 'simplifi', 'scroll', 'game', 'use', 'map', 'etc', 'fli', 'play', 'routin', 'sprite', 'anim', 'fli', 'play', 'pcx', 'support', 'soon', 'gif', 'emsxm', 'come', 'soon', 'wellleav', 'email', 'barri', 'egert', 'egerterobelixgaulcsduwocafil', 'avail', 'use', 'mget', 'wgtzipsimtel', 'two', 'zero', 'mirror', 'pd', 'one', 'msdosturbocnicfunetfi', 'pubmsdosgamesprogrammingsom', 'site', 'may', 'recent', 'file', 'contact', 'info', 'regard', 'uptod', 'inform'], ['sorri', 'genoa', 'card', 'noth', 'ati', 'ultra', 'plu', 'two', 'mbca', 'nt', 'plu', 'ati', 'cost', 'three', 'three', 'zero', 'us', 'street', 'price'], ['write', 'utili', 'convert', 'regi', 'tekton', 'esacp', 'sequenc', 'use', 'format', 'would', 'rather', 'goto', 'bitmap', 'format', 'convert',  ...
# [['recent', 'got', 'file', 'describ', 'librari', 'render', 'routin', 'call', 'sipp', 'simpl', 'polygon', 'processor', 'could', 'anyon', 'tell', 'ftp', 'sourc', 'code', 'newest', 'version', 'around', 'also', 've', 'never', 'use', 'renderman', 'wonder', 'renderman', 'like', 'sipp', 'ie', 'librari', 'render', 'routin', 'one', 'use', 'make', 'program', 'creat', 'imag', 'thank', 'joe', 'thamjo', 'tham', 'jothersysedmontonabca'], ['hello', 'everybodi', 'use', 'pixar', 'renderman', 'three', 'scene', 'descript', 'languag', 'creat', 'three', 'world', 'pleas', 'help', 'use', 'renderman', 'librari', 'next', 'document', 'nextstep', 'version', 'renderman', 'avail', 'creat', 'complic', 'scene', 'render', 'use', 'surfac', 'shader', 'bring', 'life', 'appli', 'shadow', 'reflectionsa', 'far', 'understand', 'defin', 'environment', 'shadow', 'map', 'produc', 'reflect', 'shadow', 'know', 'use', 'themani', 'advis', 'simpl', 'rib', 'exampl', 'appreciatedthank', 'advancealex', 'kolesov', 'moscow', 'russiatalu', 'imag', 'commun', 'corporationemail', 'alextalusmsksu', 'next', 'mail', 'accept'], ['anybodi', 'know', 'good', 'two', 'dgraphic', 'packag', 'avail', 'ibm', 'rs', 'six', 'zero', 'zero', 'zero', 'aix', 'look', 'someth', 'like', 'dec', 'gk', 'hewlettpackard', 'starbas', 'reason', 'good', 'support', 'differ', 'output', 'devic', 'like', 'plotter', 'termin', 'etc', 'tri', 'also', 'xgk', 'one', 'one', 'distribut', 'ibm', 'implement', 'phig', 'work', 'requir', 'output', 'devic', 'xwindow', 'salesman', 'ibm', 'familiar', 'graphic', 'expect', 'good', 'solut', 'ari', 'ari', 'suutari', 'aricarelfi', 'carelcomp', 'oy', 'lappeenranta', 'finland'], ['requir', 'bgi', 'driver', 'super', 'vga', 'display', 'super', 'xvga', 'display', 'anyon', 'know', 'could', 'obtain', 'relev', 'driver', 'ftp', 'site', 'regard', 'simon', 'crow'], ['hi', 'immedi', 'need', 'detail', 'variou', 'graphic', 'compressiontechniqu', 'know', 'could', 'obtain', 'descript', 'algorithm', 'publicdomain', 'sourc', 'code', 'format', 'jpeg', 'gif', 'andfract', 'would', 'immens', 'grate', 'could', 'share', 'info', 'withm', 'project', 'contempl', 'doingthank', 'advanc', 'pleas', 'repli', 'via', 'email', 'possiblehbj'], ['wgt', 'wordup', 'graphic', 'toolkit', 'design', 'truli', 'mycoprogramm', 'brother', 'chri', 'egert', 'turboborland', 'graphicslibrari', 'program', 'three', 'two', 'zero', 'two', 'zero', 'zero', 'two', 'five', 'six', 'vga', 'current', 'produc', 'assharewar', 'year', 'may', 'commerci', 'product', 'excus', 'typosther', 'backspac', 'termin', 'featur', 'includ', 'load', 'save', 'bitimag', 'call', 'block', 'herein', 'flip', 'resiz', 'warp', 'block', 'load', 'save', 'palett', 'fade', 'sever', 'memori', 'graphic', 'primit', 'line', 'circl', 'bar', 'rectangl', 'region', 'fill', 'usual', 'useless', 'floodfil', 'sprite', 'anim', 'bitmap', 'two', 'zero', 'zero', 'onscreen', 'joystickmous', 'support', 'sb', 'support', 'voc', 'cmf', 'tilebas', 'game', 'creation', 'use', 'one', 'six', 'one', 'six', 'pixel', 'tile', 'creat', 'three', 'two', 'zero', 'two', 'zero', 'zero', 'tile', 'map', 'game', 'world', 'like', 'duke', 'nuke', 'em', 'number', 'sprite', 'increas', 'one', 'zero', 'zero', 'zero', 'profession', 'sprite', 'creator', 'util', 'map', 'maker', 'routin', 'simplifi', 'scroll', 'game', 'use', 'map', 'etc', 'fli', 'play', 'routin', 'sprite', 'anim', 'fli', 'play', 'pcx', 'support', 'soon', 'gif', 'emsxm', 'come', 'soon', 'wellleav', 'email', 'barri', 'egert', 'egerterobelixgaulcsduwocafil', 'avail', 'use', 'mget', 'wgtzipsimtel', 'two', 'zero', 'mirror', 'pd', 'one', 'msdosturbocnicfunetfi', 'pubmsdosgamesprogrammingsom', 'site', 'may', 'recent', 'file', 'contact', 'info', 'regard', 'uptod', 'inform'], ['sorri', 'genoa', 'card', 'noth', 'ati', 'ultra', 'plu', 'two', 'mbca', 'nt', 'plu', 'ati', 'cost', 'three', 'three', 'zero', 'us', 'street', 'price'], ['write', 'utili', 'convert', 'regi', 'tekton', 'esacp', 'sequenc', 'use', 'format', 'would', 'rather', 'goto', 'bitmap', 'format', 'convert',  ...
# ...
# [['recent', 'got', 'file', 'describ', 'librari', 'render', 'routin', 'call', 'sipp', 'simpl', 'polygon', 'processor', 'could', 'anyon', 'tell', 'ftp', 'sourc', 'code', 'newest', 'version', 'around', 'also', 've', 'never', 'use', 'renderman', 'wonder', 'renderman', 'like', 'sipp', 'ie', 'librari', 'render', 'routin', 'one', 'use', 'make', 'program', 'creat', 'imag', 'thank', 'joe', 'thamjo', 'tham', 'jothersysedmontonabca'], ['hello', 'everybodi', 'use', 'pixar', 'renderman', 'three', 'scene', 'descript', 'languag', 'creat', 'three', 'world', 'pleas', 'help', 'use', 'renderman', 'librari', 'next', 'document', 'nextstep', 'version', 'renderman', 'avail', 'creat', 'complic', 'scene', 'render', 'use', 'surfac', 'shader', 'bring', 'life', 'appli', 'shadow', 'reflectionsa', 'far', 'understand', 'defin', 'environment', 'shadow', 'map', 'produc', 'reflect', 'shadow', 'know', 'use', 'themani', 'advis', 'simpl', 'rib', 'exampl', 'appreciatedthank', 'advancealex', 'kolesov', 'moscow', 'russiatalu', 'imag', 'commun', 'corporationemail', 'alextalusmsksu', 'next', 'mail', 'accept'], ['anybodi', 'know', 'good', 'two', 'dgraphic', 'packag', 'avail', 'ibm', 'rs', 'six', 'zero', 'zero', 'zero', 'aix', 'look', 'someth', 'like', 'dec', 'gk', 'hewlettpackard', 'starbas', 'reason', 'good', 'support', 'differ', 'output', 'devic', 'like', 'plotter', 'termin', 'etc', 'tri', 'also', 'xgk', 'one', 'one', 'distribut', 'ibm', 'implement', 'phig', 'work', 'requir', 'output', 'devic', 'xwindow', 'salesman', 'ibm', 'familiar', 'graphic', 'expect', 'good', 'solut', 'ari', 'ari', 'suutari', 'aricarelfi', 'carelcomp', 'oy', 'lappeenranta', 'finland'], ['requir', 'bgi', 'driver', 'super', 'vga', 'display', 'super', 'xvga', 'display', 'anyon', 'know', 'could', 'obtain', 'relev', 'driver', 'ftp', 'site', 'regard', 'simon', 'crow'], ['hi', 'immedi', 'need', 'detail', 'variou', 'graphic', 'compressiontechniqu', 'know', 'could', 'obtain', 'descript', 'algorithm', 'publicdomain', 'sourc', 'code', 'format', 'jpeg', 'gif', 'andfract', 'would', 'immens', 'grate', 'could', 'share', 'info', 'withm', 'project', 'contempl', 'doingthank', 'advanc', 'pleas', 'repli', 'via', 'email', 'possiblehbj'], ['wgt', 'wordup', 'graphic', 'toolkit', 'design', 'truli', 'mycoprogramm', 'brother', 'chri', 'egert', 'turboborland', 'graphicslibrari', 'program', 'three', 'two', 'zero', 'two', 'zero', 'zero', 'two', 'five', 'six', 'vga', 'current', 'produc', 'assharewar', 'year', 'may', 'commerci', 'product', 'excus', 'typosther', 'backspac', 'termin', 'featur', 'includ', 'load', 'save', 'bitimag', 'call', 'block', 'herein', 'flip', 'resiz', 'warp', 'block', 'load', 'save', 'palett', 'fade', 'sever', 'memori', 'graphic', 'primit', 'line', 'circl', 'bar', 'rectangl', 'region', 'fill', 'usual', 'useless', 'floodfil', 'sprite', 'anim', 'bitmap', 'two', 'zero', 'zero', 'onscreen', 'joystickmous', 'support', 'sb', 'support', 'voc', 'cmf', 'tilebas', 'game', 'creation', 'use', 'one', 'six', 'one', 'six', 'pixel', 'tile', 'creat', 'three', 'two', 'zero', 'two', 'zero', 'zero', 'tile', 'map', 'game', 'world', 'like', 'duke', 'nuke', 'em', 'number', 'sprite', 'increas', 'one', 'zero', 'zero', 'zero', 'profession', 'sprite', 'creator', 'util', 'map', 'maker', 'routin', 'simplifi', 'scroll', 'game', 'use', 'map', 'etc', 'fli', 'play', 'routin', 'sprite', 'anim', 'fli', 'play', 'pcx', 'support', 'soon', 'gif', 'emsxm', 'come', 'soon', 'wellleav', 'email', 'barri', 'egert', 'egerterobelixgaulcsduwocafil', 'avail', 'use', 'mget', 'wgtzipsimtel', 'two', 'zero', 'mirror', 'pd', 'one', 'msdosturbocnicfunetfi', 'pubmsdosgamesprogrammingsom', 'site', 'may', 'recent', 'file', 'contact', 'info', 'regard', 'uptod', 'inform'], ['sorri', 'genoa', 'card', 'noth', 'ati', 'ultra', 'plu', 'two', 'mbca', 'nt', 'plu', 'ati', 'cost', 'three', 'three', 'zero', 'us', 'street', 'price'], ['write', 'utili', 'convert', 'regi', 'tekton', 'esacp', 'sequenc', 'use', 'format', 'would', 'rather', 'goto', 'bitmap', 'format', 'convert',  ...
# [['recent', 'got', 'file', 'describ', 'librari', 'render', 'routin', 'call', 'sipp', 'simpl', 'polygon', 'processor', 'could', 'anyon', 'tell', 'ftp', 'sourc', 'code', 'newest', 'version', 'around', 'also', 've', 'never', 'use', 'renderman', 'wonder', 'renderman', 'like', 'sipp', 'ie', 'librari', 'render', 'routin', 'one', 'use', 'make', 'program', 'creat', 'imag', 'thank', 'joe', 'thamjo', 'tham', 'jothersysedmontonabca'], ['hello', 'everybodi', 'use', 'pixar', 'renderman', 'three', 'scene', 'descript', 'languag', 'creat', 'three', 'world', 'pleas', 'help', 'use', 'renderman', 'librari', 'next', 'document', 'nextstep', 'version', 'renderman', 'avail', 'creat', 'complic', 'scene', 'render', 'use', 'surfac', 'shader', 'bring', 'life', 'appli', 'shadow', 'reflectionsa', 'far', 'understand', 'defin', 'environment', 'shadow', 'map', 'produc', 'reflect', 'shadow', 'know', 'use', 'themani', 'advis', 'simpl', 'rib', 'exampl', 'appreciatedthank', 'advancealex', 'kolesov', 'moscow', 'russiatalu', 'imag', 'commun', 'corporationemail', 'alextalusmsksu', 'next', 'mail', 'accept'], ['anybodi', 'know', 'good', 'two', 'dgraphic', 'packag', 'avail', 'ibm', 'rs', 'six', 'zero', 'zero', 'zero', 'aix', 'look', 'someth', 'like', 'dec', 'gk', 'hewlettpackard', 'starbas', 'reason', 'good', 'support', 'differ', 'output', 'devic', 'like', 'plotter', 'termin', 'etc', 'tri', 'also', 'xgk', 'one', 'one', 'distribut', 'ibm', 'implement', 'phig', 'work', 'requir', 'output', 'devic', 'xwindow', 'salesman', 'ibm', 'familiar', 'graphic', 'expect', 'good', 'solut', 'ari', 'ari', 'suutari', 'aricarelfi', 'carelcomp', 'oy', 'lappeenranta', 'finland'], ['requir', 'bgi', 'driver', 'super', 'vga', 'display', 'super', 'xvga', 'display', 'anyon', 'know', 'could', 'obtain', 'relev', 'driver', 'ftp', 'site', 'regard', 'simon', 'crow'], ['hi', 'immedi', 'need', 'detail', 'variou', 'graphic', 'compressiontechniqu', 'know', 'could', 'obtain', 'descript', 'algorithm', 'publicdomain', 'sourc', 'code', 'format', 'jpeg', 'gif', 'andfract', 'would', 'immens', 'grate', 'could', 'share', 'info', 'withm', 'project', 'contempl', 'doingthank', 'advanc', 'pleas', 'repli', 'via', 'email', 'possiblehbj'], ['wgt', 'wordup', 'graphic', 'toolkit', 'design', 'truli', 'mycoprogramm', 'brother', 'chri', 'egert', 'turboborland', 'graphicslibrari', 'program', 'three', 'two', 'zero', 'two', 'zero', 'zero', 'two', 'five', 'six', 'vga', 'current', 'produc', 'assharewar', 'year', 'may', 'commerci', 'product', 'excus', 'typosther', 'backspac', 'termin', 'featur', 'includ', 'load', 'save', 'bitimag', 'call', 'block', 'herein', 'flip', 'resiz', 'warp', 'block', 'load', 'save', 'palett', 'fade', 'sever', 'memori', 'graphic', 'primit', 'line', 'circl', 'bar', 'rectangl', 'region', 'fill', 'usual', 'useless', 'floodfil', 'sprite', 'anim', 'bitmap', 'two', 'zero', 'zero', 'onscreen', 'joystickmous', 'support', 'sb', 'support', 'voc', 'cmf', 'tilebas', 'game', 'creation', 'use', 'one', 'six', 'one', 'six', 'pixel', 'tile', 'creat', 'three', 'two', 'zero', 'two', 'zero', 'zero', 'tile', 'map', 'game', 'world', 'like', 'duke', 'nuke', 'em', 'number', 'sprite', 'increas', 'one', 'zero', 'zero', 'zero', 'profession', 'sprite', 'creator', 'util', 'map', 'maker', 'routin', 'simplifi', 'scroll', 'game', 'use', 'map', 'etc', 'fli', 'play', 'routin', 'sprite', 'anim', 'fli', 'play', 'pcx', 'support', 'soon', 'gif', 'emsxm', 'come', 'soon', 'wellleav', 'email', 'barri', 'egert', 'egerterobelixgaulcsduwocafil', 'avail', 'use', 'mget', 'wgtzipsimtel', 'two', 'zero', 'mirror', 'pd', 'one', 'msdosturbocnicfunetfi', 'pubmsdosgamesprogrammingsom', 'site', 'may', 'recent', 'file', 'contact', 'info', 'regard', 'uptod', 'inform'], ['sorri', 'genoa', 'card', 'noth', 'ati', 'ultra', 'plu', 'two', 'mbca', 'nt', 'plu', 'ati', 'cost', 'three', 'three', 'zero', 'us', 'street', 'price'], ['write', 'utili', 'convert', 'regi', 'tekton', 'esacp', 'sequenc', 'use', 'format', 'would', 'rather', 'goto', 'bitmap', 'format', 'convert',  ...
# [['recent', 'got', 'file', 'describ', 'librari', 'render', 'routin', 'call', 'sipp', 'simpl', 'polygon', 'processor', 'could', 'anyon', 'tell', 'ftp', 'sourc', 'code', 'newest', 'version', 'around', 'also', 've', 'never', 'use', 'renderman', 'wonder', 'renderman', 'like', 'sipp', 'ie', 'librari', 'render', 'routin', 'one', 'use', 'make', 'program', 'creat', 'imag', 'thank', 'joe', 'thamjo', 'tham', 'jothersysedmontonabca'], ['hello', 'everybodi', 'use', 'pixar', 'renderman', 'three', 'scene', 'descript', 'languag', 'creat', 'three', 'world', 'pleas', 'help', 'use', 'renderman', 'librari', 'next', 'document', 'nextstep', 'version', 'renderman', 'avail', 'creat', 'complic', 'scene', 'render', 'use', 'surfac', 'shader', 'bring', 'life', 'appli', 'shadow', 'reflectionsa', 'far', 'understand', 'defin', 'environment', 'shadow', 'map', 'produc', 'reflect', 'shadow', 'know', 'use', 'themani', 'advis', 'simpl', 'rib', 'exampl', 'appreciatedthank', 'advancealex', 'kolesov', 'moscow', 'russiatalu', 'imag', 'commun', 'corporationemail', 'alextalusmsksu', 'next', 'mail', 'accept'], ['anybodi', 'know', 'good', 'two', 'dgraphic', 'packag', 'avail', 'ibm', 'rs', 'six', 'zero', 'zero', 'zero', 'aix', 'look', 'someth', 'like', 'dec', 'gk', 'hewlettpackard', 'starbas', 'reason', 'good', 'support', 'differ', 'output', 'devic', 'like', 'plotter', 'termin', 'etc', 'tri', 'also', 'xgk', 'one', 'one', 'distribut', 'ibm', 'implement', 'phig', 'work', 'requir', 'output', 'devic', 'xwindow', 'salesman', 'ibm', 'familiar', 'graphic', 'expect', 'good', 'solut', 'ari', 'ari', 'suutari', 'aricarelfi', 'carelcomp', 'oy', 'lappeenranta', 'finland'], ['requir', 'bgi', 'driver', 'super', 'vga', 'display', 'super', 'xvga', 'display', 'anyon', 'know', 'could', 'obtain', 'relev', 'driver', 'ftp', 'site', 'regard', 'simon', 'crow'], ['hi', 'immedi', 'need', 'detail', 'variou', 'graphic', 'compressiontechniqu', 'know', 'could', 'obtain', 'descript', 'algorithm', 'publicdomain', 'sourc', 'code', 'format', 'jpeg', 'gif', 'andfract', 'would', 'immens', 'grate', 'could', 'share', 'info', 'withm', 'project', 'contempl', 'doingthank', 'advanc', 'pleas', 'repli', 'via', 'email', 'possiblehbj'], ['wgt', 'wordup', 'graphic', 'toolkit', 'design', 'truli', 'mycoprogramm', 'brother', 'chri', 'egert', 'turboborland', 'graphicslibrari', 'program', 'three', 'two', 'zero', 'two', 'zero', 'zero', 'two', 'five', 'six', 'vga', 'current', 'produc', 'assharewar', 'year', 'may', 'commerci', 'product', 'excus', 'typosther', 'backspac', 'termin', 'featur', 'includ', 'load', 'save', 'bitimag', 'call', 'block', 'herein', 'flip', 'resiz', 'warp', 'block', 'load', 'save', 'palett', 'fade', 'sever', 'memori', 'graphic', 'primit', 'line', 'circl', 'bar', 'rectangl', 'region', 'fill', 'usual', 'useless', 'floodfil', 'sprite', 'anim', 'bitmap', 'two', 'zero', 'zero', 'onscreen', 'joystickmous', 'support', 'sb', 'support', 'voc', 'cmf', 'tilebas', 'game', 'creation', 'use', 'one', 'six', 'one', 'six', 'pixel', 'tile', 'creat', 'three', 'two', 'zero', 'two', 'zero', 'zero', 'tile', 'map', 'game', 'world', 'like', 'duke', 'nuke', 'em', 'number', 'sprite', 'increas', 'one', 'zero', 'zero', 'zero', 'profession', 'sprite', 'creator', 'util', 'map', 'maker', 'routin', 'simplifi', 'scroll', 'game', 'use', 'map', 'etc', 'fli', 'play', 'routin', 'sprite', 'anim', 'fli', 'play', 'pcx', 'support', 'soon', 'gif', 'emsxm', 'come', 'soon', 'wellleav', 'email', 'barri', 'egert', 'egerterobelixgaulcsduwocafil', 'avail', 'use', 'mget', 'wgtzipsimtel', 'two', 'zero', 'mirror', 'pd', 'one', 'msdosturbocnicfunetfi', 'pubmsdosgamesprogrammingsom', 'site', 'may', 'recent', 'file', 'contact', 'info', 'regard', 'uptod', 'inform'], ['sorri', 'genoa', 'card', 'noth', 'ati', 'ultra', 'plu', 'two', 'mbca', 'nt', 'plu', 'ati', 'cost', 'three', 'three', 'zero', 'us', 'street', 'price'], ['write', 'utili', 'convert', 'regi', 'tekton', 'esacp', 'sequenc', 'use', 'format', 'would', 'rather', 'goto', 'bitmap', 'format', 'convert',  ...
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
DF = {}
N = len(processed_text)

for i in range(N):
    tokens = processed_text[i]
    for w in tokens:
        try:
            DF[w].add(i)
        except:
            DF[w] = {i}
            
for i in DF:
    DF[i] = len(DF[i])

# %%
DF
# Out:
# {'recent': 6,
#  'got': 11,
#  'file': 23,
#  'describ': 5,
#  'librari': 11,
#  'render': 11,
#  'routin': 8,
#  'call': 9,
#  'sipp': 1,
#  'simpl': 6,
#  'polygon': 8,
#  'processor': 2,
#  'could': 26,
#  'anyon': 30,
#  'tell': 5,
#  'ftp': 20,
#  'sourc': 12,
#  'code': 16,
#  'newest': 2,
#  'version': 16,
#  'around': 8,
#  'also': 20,
#  've': 23,
#  'never': 5,
#  'use': 38,
#  'renderman': 2,
#  'wonder': 5,
#  'like': 27,
#  'ie': 11,
#  'one': 75,
#  'make': 16,
#  'program': 28,
#  'creat': 16,
#  'imag': 32,
#  'thank': 14,
#  'joe': 4,
#  'thamjo': 1,
#  'tham': 1,
#  'jothersysedmontonabca': 1,
#  'hello': 3,
#  'everybodi': 1,
#  'pixar': 2,
#  'three': 61,
#  'scene': 3,
#  'descript': 7,
#  'languag': 6,
#  'world': 5,
#  'pleas': 20,
#  'help': 29,
#  'next': 5,
#  'document': 5,
#  'nextstep': 2,
#  'avail': 14,
#  'complic': 6,
#  'surfac': 9,
#  'shader': 1,
#  'bring': 4,
#  'life': 5,
#  'appli': 6,
#  'shadow': 1,
#  'reflectionsa': 1,
#  'far': 7,
#  'understand': 6,
#  'defin': 6,
#  'environment': 2,
#  'map': 10,
#  'produc': 5,
#  'reflect': 1,
#  'know': 38,
#  'themani': 1,
#  'advis': 2,
#  'rib': 1,
#  'exampl': 9,
#  'appreciatedthank': 1,
#  'advancealex': 1,
#  'kolesov': 1,
#  'moscow': 1,
#  'russiatalu': 1,
#  'commun': 4,
#  'corporationemail': 1,
#  'alextalusmsksu': 1,
#  'mail': 11,
#  'accept': 8,
#  'anybodi': 13,
#  'good': 16,
#  'two': 65,
#  'dgraphic': 1,
#  'packag': 10,
#  'ibm': 6,
#  'rs': 4,
#  'six': 53,
#  'zero': 59,
#  'aix': 3,
#  'look': 25,
#  'someth': 14,
#  'dec': 3,
#  'gk': 2,
#  'hewlettpackard': 3,
#  'starbas': 1,
#  'reason': 6,
#  'support': 13,
#  'differ': 14,
#  'output': 10,
#  'devic': 4,
#  'plotter': 2,
#  'termin': 3,
#  'etc': 14,
#  'tri': 19,
#  'xgk': 1,
#  'distribut': 6,
#  'implement': 8,
#  'phig': 2,
#  'work': 18,
#  'requir': 8,
#  'xwindow': 3,
#  'salesman': 1,
#  'familiar': 2,
#  'graphic': 30,
#  'expect': 6,
#  'solut': 8,
#  'ari': 1,
#  'suutari': 1,
#  'aricarelfi': 1,
#  'carelcomp': 1,
#  'oy': 1,
#  'lappeenranta': 1,
#  'finland': 1,
#  'bgi': 2,
#  'driver': 7,
#  'super': 2,
#  'vga': 9,
#  'display': 15,
#  'xvga': 1,
#  'obtain': 7,
#  'relev': 2,
#  'site': 11,
#  'regard': 8,
#  'simon': 2,
#  'crow': 1,
#  'hi': 6,
#  'immedi': 2,
#  'need': 17,
#  'detail': 3,
#  'variou': 3,
#  'compressiontechniqu': 1,
#  'algorithm': 15,
#  'publicdomain': 3,
#  'format': 18,
#  'jpeg': 8,
#  'gif': 10,
#  'andfract': 1,
#  'would': 39,
#  'immens': 2,
#  'grate': 1,
#  'share': 3,
#  'info': 10,
#  'withm': 1,
#  'project': 9,
#  'contempl': 1,
#  'doingthank': 1,
#  'advanc': 8,
#  'repli': 5,
#  'via': 8,
#  'email': 24,
#  'possiblehbj': 1,
#  'wgt': 1,
#  'wordup': 1,
#  'toolkit': 3,
#  'design': 6,
#  'truli': 3,
#  'mycoprogramm': 1,
#  'brother': 2,
#  'chri': 2,
#  'egert': 1,
#  'turboborland': 1,
#  'graphicslibrari': 1,
#  'five': 49,
#  'current': 8,
#  'assharewar': 1,
#  'year': 6,
#  'may': 14,
#  'commerci': 7,
#  'product': 7,
#  'excus': 1,
#  'typosther': 1,
#  'backspac': 1,
#  'featur': 9,
#  'includ': 8,
#  'load': 5,
#  'save': 7,
#  'bitimag': 2,
#  'block': 2,
#  'herein': 2,
#  'flip': 2,
#  'resiz': 1,
#  'warp': 2,
#  'palett': 4,
#  'fade': 1,
#  'sever': 7,
#  'memori': 8,
#  'primit': 3,
#  'line': 17,
#  'circl': 2,
#  'bar': 5,
#  'rectangl': 2,
#  'region': 2,
#  'fill': 7,
#  'usual': 5,
#  'useless': 3,
#  'floodfil': 1,
#  'sprite': 1,
#  'anim': 11,
#  'bitmap': 4,
#  'onscreen': 2,
#  'joystickmous': 1,
#  'sb': 1,
#  'voc': 1,
#  'cmf': 1,
#  'tilebas': 1,
#  'game': 4,
#  'creation': 4,
#  'pixel': 11,
#  'tile': 3,
#  'duke': 1,
#  'nuke': 1,
#  'em': 2,
#  'number': 12,
#  'increas': 2,
#  'profession': 3,
#  'creator': 1,
#  'util': 7,
#  'maker': 2,
#  'simplifi': 3,
#  'scroll': 2,
#  'fli': 4,
#  'play': 5,
#  'pcx': 2,
#  'soon': 3,
#  'emsxm': 1,
#  'come': 12,
#  'wellleav': 1,
#  'barri': 1,
#  'egerterobelixgaulcsduwocafil': 1,
#  'mget': 2,
#  'wgtzipsimtel': 1,
#  'mirror': 4,
#  'pd': 4,
#  'msdosturbocnicfunetfi': 1,
#  'pubmsdosgamesprogrammingsom': 1,
#  'contact': 5,
#  'uptod': 1,
#  'inform': 15,
#  'sorri': 2,
#  'genoa': 2,
#  'card': 12,
#  'noth': 3,
#  'ati': 2,
#  'ultra': 2,
#  'plu': 5,
#  'mbca': 1,
#  'nt': 36,
#  'cost': 7,
#  'us': 8,
#  'street': 3,
#  'price': 6,
#  'write': 22,
#  'utili': 1,
#  'convert': 18,
#  'regi': 2,
#  'tekton': 1,
#  'esacp': 1,
#  'sequenc': 6,
#  'rather': 8,
#  'goto': 1,
#  'window': 12,
#  'meta': 1,
#  'easili': 5,
#  'enough': 5,
#  'corel': 1,
#  'draw': 13,
#  'cdr': 1,
#  'ms': 6,
#  'power': 4,
#  'point': 13,
#  'ppt': 1,
#  'microsoft': 3,
#  'give': 12,
#  'applic': 10,
#  'merkelbdsageccpurdueedu': 1,
#  'brian': 3,
#  'merkel': 1,
#  'writesin': 3,
#  'articl': 24,
#  'nine': 42,
#  'apr': 8,
#  'four': 57,
#  'ornlgov': 1,
#  'ednoblessacamorenortnedu': 1,
#  'edward': 1,
#  'nobl': 1,
#  'writesi': 8,
#  'view': 9,
#  'tga': 2,
#  'povray': 2,
#  'diamondspeedstar': 1,
#  'video': 9,
#  'board': 7,
#  'tojpeg': 1,
#  'cjpeg': 2,
#  'cview': 1,
#  'eight': 46,
#  'bit': 14,
#  'colori': 1,
#  'way': 11,
#  'andor': 3,
#  'biti': 1,
#  'univesa': 1,
#  'uvesa': 1,
#  'zip': 3,
#  'dvpeg': 2,
#  'viewer': 7,
#  'get': 28,
#  'anythingperhap': 1,
#  'set': 10,
#  'properli': 2,
#  'idea': 5,
#  'thispleas': 1,
#  'feel': 6,
#  'free': 8,
#  'enlighten': 2,
#  'mejust': 1,
#  'want': 17,
#  'see': 14,
#  'darn': 2,
#  'thing': 10,
#  'real': 11,
#  'colorimag': 2,
#  'alchemi': 3,
#  'aka': 2,
#  'pov': 4,
#  'think': 15,
#  'sharewar': 6,
#  'probabl': 5,
#  'somwher': 1,
#  'netland': 1,
#  'yep': 2,
#  'fine': 7,
#  'tseng': 2,
#  'dac': 1,
#  'rememberread': 1,
#  'cours': 5,
#  'still': 9,
#  'kcolor': 1,
#  'sneez': 1,
#  'flag': 1,
#  'neal': 1,
#  'miller': 1,
#  'go': 13,
#  'mad': 1,
#  'millernwcraftcampclarksonedu': 1,
#  'clarkson': 1,
#  'univers': 13,
#  'ford': 1,
#  'prefect': 1,
#  'darkcraftcampclarksonedu': 1,
#  'wed': 1,
#  'gmt': 2,
#  'graemelabtamlabtamozau': 1,
#  'graem': 1,
#  'gill': 2,
#  'saidgraem': 1,
#  'ye': 4,
#  'known': 11,
#  'bresenham': 1,
#  'run': 17,
#  'length': 3,
#  'slice': 2,
#  'forgraem': 1,
#  'increment': 1,
#  'fundament': 2,
#  'comput': 16,
#  'graphicsgraem': 1,
#  'springerverlag': 3,
#  'berlin': 2,
#  'heidelberg': 1,
#  'extrapol': 1,
#  'ca': 15,
#  'figur': 4,
#  'determin': 3,
#  'ideasgraem': 1,
#  'hmm': 1,
#  'mightgraem': 1,
#  'take': 17,
#  'followinggraem': 1,
#  'doublestep': 1,
#  'gener': 8,
#  'circlesgraem': 1,
#  'wu': 1,
#  'rokn': 1,
#  'processinggraem': 1,
#  'vol': 2,
#  'seven': 39,
#  'mar': 3,
#  'pp': 3,
#  'ellips': 2,
#  'roknegraem': 1,
#  'ieee': 2,
#  'anoth': 9,
#  'paper': 7,
#  'might': 5,
#  'consid': 3,
#  'isarticlefungdraw': 1,
#  'titlea': 1,
#  'runlength': 1,
#  'without': 12,
#  'divis': 3,
#  'oper': 5,
#  'authorkhun': 1,
#  'yee': 1,
#  'fung': 1,
#  'tina': 1,
#  'nichol': 1,
#  'dewdney': 1,
#  'journalcomput': 1,
#  'forum': 4,
#  'volum': 4,
#  'pagesc': 1,
#  'khun': 1,
#  'yeekhun': 1,
#  'clippercsduwocadepart': 1,
#  'sciencemiddlesex': 1,
#  'collegeunivers': 1,
#  'western': 1,
#  'ontariolondon': 1,
#  'ontariocanada': 1,
#  'tel': 5,
#  'fax': 9,
#  'pdxgateuucp': 1,
#  'idrrigelcspdxedu': 1,
#  'ian': 2,
#  'romanick': 1,
#  'talk': 3,
#  'yield': 1,
#  'compress': 6,
#  'loss': 2,
#  'notic': 5,
#  'back': 11,
#  'hell': 2,
#  'long': 4,
#  'time': 15,
#  'll': 11,
#  'find': 16,
#  'book': 9,
#  'exact': 2,
#  'ttylthat': 1,
#  'typic': 4,
#  'claim': 3,
#  'though': 7,
#  'say': 12,
#  'improvedcompress': 1,
#  'speed': 7,
#  'consider': 2,
#  'anyth': 5,
#  'elseabout': 1,
#  'interest': 13,
#  'meani': 1,
#  'pointersreportedli': 1,
#  'earli': 3,
#  'fractal': 3,
#  'hour': 1,
#  'usedthat': 1,
#  'marvel': 1,
#  'piec': 2,
#  'hardwar': 6,
#  'grad': 1,
#  'student': 2,
#  'thework': 1,
#  'supposedli': 3,
#  'autom': 4,
#  'sinc': 10,
#  'stillwait': 1,
#  'impressedallen': 1,
#  'sign': 1,
#  'cynic': 1,
#  'vesa': 5,
#  'tsr': 2,
#  'report': 4,
#  'crt': 1,
#  'regist': 4,
#  'state': 6,
#  'mode': 9,
#  'serg': 1,
#  'ivanov': 1,
#  'sergeargusmsksu': 1,
#  'eisa': 1,
#  'local': 5,
#  'bu': 1,
#  'least': 5,
#  'resolut': 9,
#  'matrox': 3,
#  'expens': 4,
#  'theother': 1,
#  'resoult': 1,
#  'striaght': 1,
#  'isa': 2,
#  'server': 6,
#  'unix': 8,
#  'pc': 7,
#  'bitsthank': 1,
#  'saw': 4,
#  'latest': 4,
#  'shopper': 1,
#  'articleon': 1,
#  'nice': 13,
#  'pretti': 6,
#  'list': 7,
#  'workshop': 3,
#  'found': 9,
#  'viaarchi': 1,
#  'draft': 1,
#  'choic': 2,
#  'old': 5,
#  'rest': 2,
#  'findso': 1,
#  'follow': 7,
#  'programsvia': 1,
#  'anonym': 6,
#  'let': 10,
#  'knowadkin': 1,
#  'ag': 1,
#  'zipdraft': 1,
#  'draftczipenvis': 1,
#  'publish': 7,
#  'envi': 1,
#  'zipneopaint': 1,
#  'neopntzipthanx': 1,
#  'advancedpetro': 1,
#  'david': 5,
#  'petro': 1,
#  'kwyjibo': 1,
#  'big': 7,
#  'dumb': 1,
#  'bald': 1,
#  'dept': 7,
#  'physic': 3,
#  'north': 4,
#  'american': 3,
#  'ape': 2,
#  'windsor': 1,
#  'petroserveruwindsorca': 1,
#  'uk': 6,
#  'bullcouk': 1,
#  'scrowehemelbullcouk': 1,
#  'given': 6,
#  'bound': 1,
#  'refer': 9,
#  'contain': 8,
#  'subject': 6,
#  'function': 7,
#  'puntbinnenpolygoon': 1,
#  'auteur': 1,
#  'corn': 1,
#  'wessel': 1,
#  'datum': 1,
#  'omschrijv': 1,
#  'bepaalt': 1,
#  'de': 3,
#  'aangeboden': 1,
#  'vector': 3,
#  'binnen': 1,
#  'op': 2,
#  'rand': 1,
#  'van': 3,
#  'het': 1,
#  'polygoon': 1,
#  'valt': 1,
#  'wijzigingen': 1,
#  'clibstatu': 1,
#  'index': 5,
#  'aantalsnijpunten': 1,
#  'geefpolygoonlengtep': 1,
#  'geefpolygoonrandpunt': 1,
#  'nn': 3,
#  'ox': 1,
#  'px': 1,
#  'vx': 1,
#  'wx': 2,
#  'interpoleerlineair': 1,
#  'wy': 1,
#  'py': 1,
#  'returnclibsucc': 1,
#  'els': 9,
#  'kopieervector': 1,
#  'returncliberbuiten': 1,
#  'wesselskrommenoord': 1,
#  'zt': 1,
#  'rotterdamth': 1,
#  'netherland': 5,
#  'kewebskeweatrbsonl': 1,
#  'simul': 2,
#  'revers': 2,
#  'neg': 1,
#  'color': 15,
#  'videomathemat': 1,
#  'transform': 6,
#  'simplerevers': 1,
#  'hue': 2,
#  'valu': 8,
#  'hsv': 2,
#  'space': 7,
#  'ita': 1,
#  'manipul': 6,
#  'yuv': 2,
#  'relatedto': 1,
#  'solarizationif': 1,
#  'wild': 1,
#  'turn': 5,
#  'therevers': 1,
#  'effect': 7,
#  'camcord': 1,
#  'equippedand': 1,
#  'monitor': 7,
#  'chaoticdynam': 1,
#  'system': 18,
#  'whose': 5,
#  'phase': 3,
#  'continu': 1,
#  'alongrot': 1,
#  'zoom': 4,
#  'focu': 1,
#  'surpris': 1,
#  'love': 3,
#  'effectwithout': 1,
#  'analog': 2,
#  'grung': 1,
#  'havepleas': 1,
#  'post': 16,
#  'summarythank': 2,
#  'lanc': 1,
#  'norskogthinmannetcomcomdata': 1,
#  'knowledg': 3,
#  'wisdom': 1,
#  'juyzalymurdochaccvirginiaedu': 1,
#  'rw': 1,
#  'vuvacscsvirginiaedu': 1,
#  'richard': 3,
#  'stoakley': 1,
#  'concav': 1,
#  'convex': 4,
#  'convers': 7,
#  'routinei': 1,
#  'coupl': 6,
#  'much': 13,
#  'luck': 2,
#  'respons': 3,
#  'iwil': 1,
#  'summari': 3,
#  'yourichard': 1,
#  'stoakleyrw': 1,
#  'vuvacscsvirginiaeduth': 1,
#  'problem': 16,
#  'precis': 6,
#  'findth': 2,
#  'smallest': 1,
#  'enclos': 1,
#  'thenyou': 1,
#  'seek': 2,
#  'hull': 2,
#  'origin': 10,
#  'therear': 1,
#  'somewhat': 2,
#  'tricki': 2,
#  'bynow': 1,
#  'wellexamin': 1,
#  'lineartim': 1,
#  'exploit': 3,
#  'boundaryor': 1,
#  'feed': 2,
#  'vertic': 4,
#  'hullroutin': 1,
#  'log': 3,
#  'method': 4,
#  'discuss': 10,
#  'inpreparata': 1,
#  'shamo': 1,
#  'archivenam': 3,
#  'graphicsresourceslistpart': 2,
#  'lastmodifi': 2,
#  'resourc': 5,
#  'weekli': 2,
#  'part': 7,
#  'last': 6,
#  'chang': 9,
#  'april': 3,
#  'plot': 3,
#  'packagesgnuplot': 1,
#  'best': 7,
#  'onlin': 4,
#  'helpit': 1,
#  'commandlin': 1,
#  'driven': 1,
#  'interact': 3,
#  'msdo': 4,
#  'amiga': 5,
#  'archimed': 2,
#  'vm': 2,
#  'platform': 5,
#  'freeli': 3,
#  'mani': 8,
#  'printer': 3,
#  'extens': 4,
#  'new': 13,
#  'compsourcesmisc': 2,
#  'patch': 2,
#  'practic': 2,
#  'everywher': 3,
#  'archi': 3,
#  'near': 1,
#  'compgraphicsgnuplot': 1,
#  'newsgroup': 7,
#  'devot': 1,
#  'gnuplotxvgr': 1,
#  'xmgr': 1,
#  'acegr': 1,
#  'xyplot': 1,
#  'tool': 5,
#  'workstat': 6,
#  'openwindow': 2,
#  'xview': 2,
#  'xvgr': 1,
#  'sun': 4,
#  'collect': 2,
#  'compil': 7,
#  'motif': 2,
#  'check': 9,
#  'ftpccalmrogiedu': 1,
#  'ccalmrpubacegrxmgr': 1,
#  'tarz': 2,
#  'ccalmrpubacegrxvgr': 1,
#  'comment': 3,
#  'suggest': 7,
#  'bug': 5,
#  'paul': 3,
#  'turner': 2,
#  'pturneramb': 1,
#  'eseogiedu': 1,
#  'fail': 2,
#  'pturnereseogiedu': 1,
#  'due': 5,
#  'constraint': 2,
#  'betweenrobot': 1,
#  'releas': 4,
#  'limit': 5,
#  'base': 9,
#  'written': 4,
#  'fortran': 2,
#  'translat': 4,
#  'mainli': 2,
#  'test': 8,
#  'less': 10,
#  'decstat': 2,
#  'ftpastropsuedu': 1,
#  'pubastrodvg': 1,
#  'callabl': 1,
#  'sunspotceeenistgov': 1,
#  'xgobi': 1,
#  'develop': 5,
#  'bellcor': 1,
#  'special': 5,
#  'multidimension': 1,
#  'data': 11,
#  'analysi': 2,
#  'explor': 2,
#  'client': 2,
#  'athena': 1,
#  'widget': 2,
#  'ascii': 2,
#  'charg': 2,
#  'statlib': 1,
#  'cmu': 1,
#  'send': 10,
#  'statlibtemperstatcmuedu': 1,
#  'bodi': 4,
#  'area': 6,
#  'messag': 2,
#  'put': 6,
#  'pick': 4,
#  'connect': 2,
#  'libstatcmuedu': 1,
#  'address': 8,
#  'password': 2,
#  'type': 8,
#  'cd': 2,
#  'warn': 2,
#  'mb': 6,
#  'larg': 5,
#  'postscript': 4,
#  'manual': 6,
#  'read': 9,
#  'readm': 4,
#  'decid': 6,
#  'whether': 5,
#  'notpgplot': 1,
#  'vaxvm': 1,
#  'copyright': 3,
#  'nomin': 2,
#  'fee': 3,
#  'contour': 3,
#  'ps': 1,
#  'tjpdeimoscaltecheduggraph': 1,
#  'host': 4,
#  'shortycswiscedu': 1,
#  'pubggraphtarz': 1,
#  'unknown': 2,
#  'detailsepigraph': 1,
#  'dvjlab': 1,
#  'physlguspbsu': 1,
#  'vladimir': 1,
#  'dmitriev': 1,
#  'demo': 4,
#  'sent': 2,
#  'budapest': 1,
#  'posta': 1,
#  'fiok': 1,
#  'hungari': 1,
#  'phfax': 1,
#  'ph': 2,
#  'multiplot': 1,
#  'xln': 1,
#  'usd': 1,
#  'aust': 1,
#  'dr': 3,
#  'alan': 1,
#  'baxter': 1,
#  'agb': 1,
#  'mbucbiocamacuk': 1,
#  'cambridg': 2,
#  'depart': 4,
#  'patholog': 1,
#  'tenni': 1,
#  'court': 2,
#  'road': 2,
#  'cb': 1,
#  'qp': 1,
#  'ukathena': 1,
#  'gregori': 1,
#  'bond': 2,
#  'beta': 1,
#  'ad': 6,
#  'stuff': 4,
#  'scientif': 2,
#  'graph': 6,
#  'axe': 1,
#  'scalabl': 1,
#  'xylineplot': 1,
#  'callback': 1,
#  'eg': 5,
#  'request': 5,
#  'pointer': 3,
#  'posit': 5,
#  'cut': 4,
#  'zoomingin': 1,
#  'fix': 6,
#  'improv': 3,
#  'addit': 4,
#  'changesextens': 1,
#  'besid': 3,
#  'frame': 6,
#  'subgrid': 1,
#  'subtic': 1,
#  'linespoint': 1,
#  'impuls': 2,
#  'linesimpuls': 1,
#  'step': 3,
#  'style': 1,
#  'solid': 2,
#  'dot': 2,
#  'dash': 1,
#  'dotdash': 1,
#  'marker': 1,
#  'legend': 1,
#  'right': 7,
#  'left': 5,
#  'hand': 6,
#  'side': 3,
#  'option': 6,
#  'pixmap': 2,
#  'instead': 6,
#  'layout': 1,
#  'align': 1,
#  'axi': 1,
#  'multipl': 5,
#  'exportlcsmitedu': 3,
#  'directori': 6,
#  'contribplottersciplot': 1,
#  'sciplot': 1,
#  'import': 2,
#  'export': 2,
#  'ep': 1,
#  'copi': 8,
#  'past': 1,
#  'buffer': 6,
#  'select': 5,
#  'open': 10,
#  'automat': 4,
#  'subview': 1,
#  'linear': 2,
#  'logarithm': 1,
#  'text': 9,
#  'normal': 6,
#  'move': 6,
#  'edit': 4,
#  'editor': 4,
#  'sort': 6,
#  'absoluterel': 1,
#  'error': 9,
#  'calcul': 4,
#  'background': 2,
#  'subtract': 1,
#  'linearshirleytougaard': 1,
#  'bezier': 3,
#  'integr': 4,
#  'rel': 3,
#  'fit': 5,
#  'regress': 1,
#  'sin': 1,
#  'co': 3,
#  'spline': 3,
#  'interpol': 4,
#  'squar': 1,
#  'smooth': 2,
#  'fft': 2,
#  'differenti': 2,
#  'esca': 1,
#  'databas': 5,
#  'ftpcstuberlind': 1,
#  'pubnextsciencesciplot': 1,
#  'author': 4,
#  'michael': 7,
#  'wesemann': 1,
#  'scillerstr': 1,
#  'germani': 1,
#  'mikefiaskorzberlinmpgdeplplot': 1,
#  'plplot': 1,
#  'small': 8,
#  'micro': 1,
#  'alik': 1,
#  'despit': 1,
#  'size': 5,
#  'quick': 1,
#  'satisfi': 2,
#  'user': 5,
#  'standard': 9,
#  'xy': 3,
#  'semilog': 1,
#  'loglog': 1,
#  'mesh': 2,
#  'chart': 2,
#  'pie': 1,
#  'place': 4,
#  'singl': 3,
#  'page': 6,
#  'width': 1,
#  'virtual': 5,
#  'infinit': 2,
#  'distinct': 2,
#  'pattern': 3,
#  'almost': 5,
#  'charact': 4,
#  'extend': 5,
#  'font': 4,
#  'greek': 1,
#  'alphabet': 1,
#  'mathemat': 2,
#  'music': 3,
#  'symbol': 1,
#  'scale': 4,
#  'depend': 5,
#  'portabl': 2,
#  'metafil': 1,
#  'hagarphutexasedu': 1,
#  'pubplplot': 1,
#  'present': 9,
#  'suno': 1,
#  'hpux': 3,
#  'unico': 1,
#  'dgux': 1,
#  'ultrix': 2,
#  'amigaexec': 1,
#  'os': 5,
#  'main': 2,
#  'mauric': 2,
#  'lebrun': 1,
#  'mjlfusionphutexasedu': 1,
#  'kernel': 1,
#  'xterm': 1,
#  'tektronix': 1,
#  'geoff': 1,
#  'furnish': 1,
#  'furnishfusionphutexasedu': 1,
#  ...}

# %%
total_vocab_size = len(DF)
print(total_vocab_size)
# Out:
# 6538

# %%
total_vocab = [x for x in DF]
print(total_vocab[:5])
# Out:
# ['recent', 'got', 'file', 'describ', 'librari']

# %%
def doc_freq(word):
    c= 0 
    try:
        c=DF[word]
    except:
        pass
    return c
WORD="path"
print("Word: ",WORD, "-->frequncy:",doc_freq(WORD))
# Out:
# Word:  path -->frequncy: 0

# %%
doc = 0

tf_idf = {}

for i in range(N):
    
    tokens = processed_text[i]
    
    counter = Counter(tokens + processed_text[i])
    words_count = len(tokens + processed_text[i])
    
    for token in np.unique(tokens):
        
        tf = counter[token]/words_count
        df = doc_freq(token)
        idf = np.log((N + 1)/(df + 1))
        
        tf_idf[doc,token] = tf * idf
        
    doc += 1

# %%
tf_idf
# Out:
# {(0, 'also'): 0.03490217953595192,
#  (0, 'anyon'): 0.02624740694124696,
#  (0, 'around'): 0.05373102087788978,
#  (0, 'call'): 0.05138967608549364,
#  (0, 'code'): 0.03959793717300097,
#  (0, 'could'): 0.0293174144630429,
#  (0, 'creat'): 0.03959793717300097,
#  (0, 'describ'): 0.06274135661362676,
#  (0, 'file'): 0.03193481525540697,
#  (0, 'ftp'): 0.03490217953595192,
#  (0, 'got'): 0.04733808593451687,
#  (1, 'russiatalu'): 0.06225354502033832,
#  (1, 'scene'): 0.10250241764194822,
#  (1, 'shader'): 0.06225354502033832,
#  (1, 'shadow'): 0.18676063506101495,
#  (1, 'simpl'): 0.04236841853628486,
#  (1, 'surfac'): 0.03670691148963831,
#  (1, 'themani'): 0.06225354502033832,
#  (1, 'three'): 0.015491623231624379,
#  (1, 'understand'): 0.04236841853628486,
#  (1, 'use'): 0.06041643623565797,
#  (1, 'version'): 0.02828424083785783,
#  (1, 'world'): 0.044815254724019114,
#  (2, 'aix'): 0.05381376926202281,
#  (2, 'also'): 0.026176634651963942,
#  (2, 'anybodi'): 0.03293438645376668,
#  (2, 'ari'): 0.13073244454271046,
#  (2, 'aricarelfi'): 0.06536622227135523,
#  (2, 'avail'): 0.03178450526231749,
#  (2, 'carelcomp'): 0.06536622227135523,
#  (2, 'dec'): 0.05381376926202281,
#  (2, 'devic'): 0.10018942014690531,
#  (2, 'dgraphic'): 0.06536622227135523,
#  (2, 'differ'): 0.03178450526231749,
#  (2, 'distribut'): 0.0444868394630991,
#  (2, 'etc'): 0.03178450526231749,
#  (2, 'expect'): 0.0444868394630991,
#  (2, 'familiar'): 0.0586084704695525,
#  (2, 'finland'): 0.06536622227135523,
#  (2, 'gk'): 0.0586084704695525,
#  (2, 'good'): 0.08909535863925218,
#  (2, 'graphic'): 0.01968555520593522,
#  (2, 'hewlettpackard'): 0.05381376926202281,
#  (2, 'ibm'): 0.13346051838929732,
#  (2, 'implement'): 0.040298265658417334,
#  (2, 'know'): 0.015859314511860217,
#  (2, 'lappeenranta'): 0.06536622227135523,
#  (2, 'like'): 0.04276386688886852,
#  (2, 'look'): 0.022617066313662955,
#  (2, 'one'): 0.009479572551830946,
#  (2, 'output'): 0.07390750813476296,
#  (2, 'oy'): 0.06536622227135523,
#  (2, 'packag'): 0.03695375406738148,
#  (2, 'phig'): 0.0586084704695525,
#  (2, 'plotter'): 0.0586084704695525,
#  (2, 'reason'): 0.0444868394630991,
#  (2, 'requir'): 0.040298265658417334,
#  (2, 'rs'): 0.050094710073452654,
#  (2, 'salesman'): 0.06536622227135523,
#  (2, 'six'): 0.010435607837949753,
#  (2, 'solut'): 0.040298265658417334,
#  (2, 'someth'): 0.03178450526231749,
#  (2, 'starbas'): 0.06536622227135523,
#  (2, 'support'): 0.03293438645376668,
#  (2, 'suutari'): 0.06536622227135523,
#  (2, 'termin'): 0.05381376926202281,
#  (2, 'tri'): 0.026989804054787805,
#  (2, 'two'): 0.007091096246913898,
#  (2, 'work'): 0.027844692294580316,
#  (2, 'xgk'): 0.06536622227135523,
#  (2, 'xwindow'): 0.05381376926202281,
#  (2, 'zero'): 0.026038797730957942,
#  (3, 'anyon'): 0.05905666561780566,
#  (3, 'bgi'): 0.17582541140865748,
#  (3, 'could'): 0.06596418254184652,
#  (3, 'crow'): 0.19609866681406574,
#  (3, 'display'): 0.18425317946014785,
#  (3, 'driver'): 0.25356789751614234,
#  (3, 'ftp'): 0.07852990395589182,
#  (17, 'aip'): 0.0037776664768650685,
#  (17, 'aipd'): 0.0007555332953730138,
#  (17, 'aipsmailnraoedu'): 0.0007555332953730138,
#  (17, 'air'): 0.0007555332953730138,
#  (17, 'aix'): 0.000622004653384968,
#  (17, 'alan'): 0.0007555332953730138,
#  (17, 'albedo'): 0.0007555332953730138,
#  (17, 'algorithm'): 0.0014197894776355063,
#  (17, 'align'): 0.0007555332953730138,
#  (17, 'alik'): 0.0007555332953730138,
#  (17, 'allegro'): 0.0007555332953730138,
#  (17, 'alliant'): 0.0007555332953730138,
#  (17, 'allow'): 0.004009404510619327,
#  (17, 'almost'): 0.002175581620198963,
#  (17, 'along'): 0.0004884760113969223,
#  (17, 'alphabet'): 0.0007555332953730138,
#  (17, 'alreadi'): 0.0005438954050497408,
#  (17, 'also'): 0.005446111620905617,
#  (17, 'alter'): 0.001244009306769936,
#  (17, 'altogeth'): 0.0007555332953730138,
#  (17, 'altsciastroaip'): 0.0007555332953730138,
#  (17, 'alvusersrequestcsbrisacukaip'): 0.0007555332953730138,
#  (17, 'alwnihgov'): 0.0007555332953730138,
#  (17, 'amiga'): 0.002175581620198963,
#  (17, 'amigaexec'): 0.0007555332953730138,
#  (17, 'among'): 0.0023160721282274393,
#  (17, 'amount'): 0.0010283992940805034,
#  (17, 'amregrdukeedu'): 0.0007555332953730138,
#  (17, 'analysi'): 0.019645297364095808,
#  (17, 'analysisimag'): 0.0007555332953730138,
#  (17, 'analyst'): 0.005288733067611096,
#  (17, 'analyt'): 0.0007555332953730138,
#  (17, 'analyz'): 0.0006774240470377866,
#  (17, 'anaysi'): 0.0007555332953730138,
#  (17, 'andrewcmuedu'): 0.0006774240470377866,
#  (17, 'angl'): 0.0020322721411133596,
#  (17, 'angleo'): 0.0007555332953730138,
#  (17, 'anim'): 0.00041036676306169506,
#  (17, 'announc'): 0.0006774240470377866,
#  (17, 'anonym'): 0.00308519788224151,
#  (17, 'anoth'): 0.0004454893900688141,
#  (17, 'anumicroimag'): 0.0007555332953730138,
#  (17, 'apertur'): 0.0015110665907460275,
#  (17, 'apollo'): 0.0006774240470377866,
#  (17, 'appar'): 0.0005790180320568598,
#  (17, 'appear'): 0.0005438954050497408,
#  (17, 'appli'): 0.0005141996470402517,
#  ...}

# %%
tf_idf[(0 , 'recent')]
# Out:
# 0.05931578595079881

# %%
def matching_score(k, query):
    preprocessed_query = preprocess(query)
    tokens = word_tokenize(str(preprocessed_query))
    print("Matching Score")
    print("\nQuery:", query)
    print("")
    print(tokens)

    query_weights = {} 
    for key in tf_idf:

        if key[1] in tokens:
            try:
                query_weights[key[0]] += tf_idf[key]
            except:
                query_weights[key[0]] = tf_idf[key]

    query_weights = sorted(query_weights.items(),key=lambda x: x[1],reverse=True)
    print("")

    l = []

    for i in query_weights[:k]:
        l.append(i[0])

    print(l)

matching_score(2,"I recently got a file describing a library")
# Out:
# No Header
# Matching Score
#
# Query: I recently got a file describing a library
#
# ['recent', 'got', 'file', 'describ', 'librari']
#
# [0, 62]
